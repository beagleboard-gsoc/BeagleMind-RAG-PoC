# %%
import requests
from bs4 import BeautifulSoup, XMLParsedAsHTMLWarning
from urllib.parse import urljoin
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
import warnings

# %%
# Suppress XMLParsedAsHTML warnings
warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)

def fetch_links(url, start_url, visited, lock):
    new_links = set()
    try:
        response = requests.get(url, timeout=5)
        soup = BeautifulSoup(response.text, 'html.parser')
        for a_tag in soup.find_all('a', href=True):
            full_url = urljoin(url, a_tag['href'])
            if full_url.startswith(start_url):
                with lock:
                    if full_url not in visited:
                        new_links.add(full_url)
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
    return url, new_links

def get_all_links(start_url, max_workers=128):
    visited = set()
    to_visit = [start_url]
    lock = threading.Lock()

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        while to_visit:
            futures = []
            with lock:
                current_batch = to_visit[:]
                to_visit = []

            for url in current_batch:
                with lock:
                    visited.add(url)
                    print(f"[✓] Visited: {url}")
                futures.append(executor.submit(fetch_links, url, start_url, visited, lock))

            for future in as_completed(futures):
                _, new_links = future.result()
                with lock:
                    for link in new_links:
                        if link not in visited and link not in to_visit:
                            to_visit.append(link)

    print(f"\n🎉 Done! Collected {len(visited)} links.")
    # Save visited links to a txt file
    with open("visited_links.txt", "w") as f:
        for link in visited:
            f.write(link + "\n")
    return visited

# Example usage
get_all_links("https://forum.beagleboard.org/")

# %%
# filter_threads.py
# Filters and sorts discussion thread links from visited_links.txt
import re
from collections import defaultdict

input_file = 'visited_links.txt'
output_file = 'filtered_threads.txt'

thread_links = defaultdict(list)
thread_pattern = re.compile(r'(https?://forum\.beagleboard\.org/t/[^/]+/\d+)(?:/(\d+))?')

with open(input_file, 'r') as f:
    for line in f:
        line = line.strip()
        # Only keep /t/ links, skip /u/ links
        match = thread_pattern.match(line)
        if match:
            thread_base = match.group(1)
            reply_num = int(match.group(2)) if match.group(2) else 0
            thread_links[thread_base].append((reply_num, line))

# Sort threads and replies
sorted_links = []
for thread_base in sorted(thread_links.keys()):
    replies = sorted(thread_links[thread_base], key=lambda x: x[0])
    sorted_links.extend([link for _, link in replies])

with open(output_file, 'w') as f:
    for link in sorted_links:
        f.write(link + '\n')

print(f"Filtered and sorted links written to {output_file}")
# Out:
# Filtered and sorted links written to filtered_threads.txt

# %%
import json
import time
from bs4 import BeautifulSoup
import requests

def fetch_thread_content(thread_urls, delay=0.2):

    threads_content = {}
    for thread_url in thread_urls:
        # Get thread base URL (remove /<reply_num> if present)
        base_url = thread_url.rsplit('/', 1)[0] if thread_url.rsplit('/', 1)[-1].isdigit() else thread_url
        if base_url not in threads_content:
            threads_content[base_url] = []

        try:
            response = requests.get(thread_url, timeout=10)
            soup = BeautifulSoup(response.text, 'html.parser')
            # Extract main post content (Discourse: <div class="cooked">)
            cooked = soup.find('div', class_='cooked')
            text = cooked.get_text(separator='\n', strip=True) if cooked else ''
            print(f"Fetched {thread_url} ({len(text)} characters)")
            threads_content[base_url].append(text)
        except Exception as e:
            print(f"Failed to fetch {thread_url}: {e}")
        time.sleep(delay)  # Be polite to the server

    # Join replies for each thread
    threads_content_joined = {url: '\n'.join(filter(None, replies)) for url, replies in threads_content.items()}

    # Save to JSON file
    with open('threads_content.json', 'w', encoding='utf-8') as jf:
        json.dump(threads_content_joined, jf, ensure_ascii=False, indent=2)

    print("Thread contents saved to threads_content.json")

# Example usage:
fetch_thread_content(sorted_links)
# Out:
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318/49 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2025-gsoc-repositories/42207 (0 characters)
# Fetched https://forum.beagleboard.org/t/3-19-versus-4-0-dtb-rebuilder/22506 (0 characters)
# Fetched https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black/178 (0 characters)
# Fetched https://forum.beagleboard.org/t/a-beginners-crysis-on-displays-and-everything-else/32782#post_4 (0 characters)
# Fetched https://forum.beagleboard.org/t/a-beginners-crysis-on-displays-and-everything-else/32782 (0 characters)
# Fetched https://forum.beagleboard.org/t/a-beginners-crysis-on-displays-and-everything-else/32782/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/a-discussion-related-to-platform-io-support-for-beagle-boards/40944 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-google-summer-of-code/27544 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-beagleboard-x15-category/28745 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-beaglev-category/28746 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-faq-category/30739 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-general-discussion-category/27532 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-googlegroups-category/18 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-job-board-category/30698 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#open-chip-organizations (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#open-chip-projects (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#open-process-data (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#links-to-resources (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#open-core-and-peripheral-projects (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#why-open-chips (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#shuttle-informationhttpsenwikipediaorgwikimulti-project_wafer_service (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#other-resources (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#other-toolchains (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-open-chips-category/29029#open-source-toolchains (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-site-feedback-category/1 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-to-do-projects-category/39262 (0 characters)
# Fetched https://forum.beagleboard.org/t/about-the-videos-category/35871 (0 characters)
# Fetched https://forum.beagleboard.org/t/accessing-beagleplay-gpios-and-csi/34390#post_12 (0 characters)
# Fetched https://forum.beagleboard.org/t/accessing-beagleplay-gpios-and-csi/34390 (0 characters)
# Fetched https://forum.beagleboard.org/t/accessing-beagleplay-gpios-and-csi/34390/12 (0 characters)
# Fetched https://forum.beagleboard.org/t/accessing-p9-pins-via-devmem2/37648 (0 characters)
# Fetched https://forum.beagleboard.org/t/adattatore-usb-wi-fi-per-beaglebone-black/34354 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594#post_13 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594#network-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594#configuration-files-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-froze-after-using-the-latest-image/33594/13 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-gpio-sysfs/32268/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-how-to-flash-emmc/32384/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-how-to-flash-emmc/32384/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-pwm-fan-debian-12-11-kernel-6-12/42193 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315#post_9 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315#post_10 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315/8 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315/9 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-running-code-from-r5f-cores/32315/10 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-streaming-h-264-encoded-video-from-an-imx219-csi-2-camera/34454 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-streaming-h-264-encoded-video-from-an-imx219-csi-2-camera/34454#post_2 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-streaming-h-264-encoded-video-from-an-imx219-csi-2-camera/34454/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-usb-interface-not-found/34303 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-usb-interface-not-found/34303#post_16 (0 characters)
# Fetched https://forum.beagleboard.org/t/ai-64-usb-interface-not-found/34303/16 (0 characters)
# Fetched https://forum.beagleboard.org/t/alsa-drivers-for-es9080q-and-tlv320aic3104/41532 (0 characters)
# Fetched https://forum.beagleboard.org/t/am335x-boneblue-dts-on-debian-11-x-iot-issue-id-like-to-contribute-the-fix/33483 (0 characters)
# Fetched https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662 (0 characters)
# Fetched https://forum.beagleboard.org/t/am5729-debian-10-3-2020-04-06-device-tree/35748 (0 characters)
# Fetched https://forum.beagleboard.org/t/android-12l-for-beagleboard-x15/32757 (0 characters)
# Fetched https://forum.beagleboard.org/t/apb-read-write/41929 (0 characters)
# Fetched https://forum.beagleboard.org/t/archive-2022-01-01-debian-10-x-buster-monthly-snapshots/31462 (0 characters)
# Fetched https://forum.beagleboard.org/t/archive-2022-01-01-debian-11-x-bullseye-monthly-snapshots/31463/9 (0 characters)
# Fetched https://forum.beagleboard.org/t/archive-2022-01-01-debian-11-x-bullseye-monthly-snapshots/31463/10 (0 characters)
# Fetched https://forum.beagleboard.org/t/archive-arm64-debian-11-x-bullseye-monthly-snapshots-2023-07-01/35563 (0 characters)
# Fetched https://forum.beagleboard.org/t/archlinux-and-gentoo-on-beagleplay/41866 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#flash-emmc-thru-boot-menu-6 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#wifi-configuration-thru-wpa_cli-4 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#debian-11x-bullseye-xfce-desktop-snapshot-11 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#network-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#debian-11x-bullseye-home-assistant-snapshot-14 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#current-built-in-overlays-10 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#emmc-flasher-7 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#debian-11x-bullseye-xfce-desktop-snapshot-12 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#debian-11x-bullseye-minimal-snapshot-11 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#wifi-configuration-wpa_supplicant-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#update-u-boot-5 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#nodered-port-1880-9 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#configuration-files-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#debian-11x-bullseye-ti-edgeai-xfce-desktop-snapshot-13 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318#cloud-9-vscode-port-3000-8 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#configuration-files-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#network-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#debian-11x-bullseye-xfce-desktop-snapshot-12 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#cloud-9-vscode-port-3000-8 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#nodered-port-1880-9 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#debian-11x-bullseye-minimal-snapshot-11 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#wifi-configuration-thru-wpa_cli-4 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#emmc-flasher-7 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#flash-emmc-thru-boot-menu-6 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#debian-11x-bullseye-ti-edgeai-xfce-desktop-snapshot-13 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#update-u-boot-5 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#debian-11x-bullseye-home-assistant-snapshot-14 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#wifi-configuration-wpa_supplicant-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-10-07/32318#current-built-in-overlays-10 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#configuration-files-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#debian-12x-bookworm-minimal-snapshot-11 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#flash-emmc-thru-boot-menu-6 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#current-built-in-overlays-10 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#wifi-configuration-thru-wpa_cli-4 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#update-u-boot-5 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#network-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#cloud-9-vscode-port-3000-8 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#emmc-flasher-7 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#wifi-configuration-wpa_supplicant-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565#nodered-port-1880-9 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#flash-emmc-thru-boot-menu-6 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#wifi-configuration-wpa_supplicant-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#wifi-configuration-thru-wpa_cli-4 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#current-built-in-overlays-10 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#network-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#update-u-boot-5 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#emmc-flasher-7 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#cloud-9-vscode-port-3000-8 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#debian-12x-bookworm-minimal-snapshot-11 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#nodered-port-1880-9 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565#configuration-files-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565 (0 characters)
# Fetched https://forum.beagleboard.org/t/armhf-debian-10-x-11-x-12-x-kernel-updates/30928 (0 characters)
# Fetched https://forum.beagleboard.org/t/balenaetcher-known-good-versions/41655 (0 characters)
# Fetched https://forum.beagleboard.org/t/bb-ai-64-does-not-show-on-tether-to-pc-on-first-startup/36901/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bb-ai-64-does-not-show-on-tether-to-pc-on-first-startup/36901/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/bb-ai64-gpio-basics/36032 (0 characters)
# Fetched https://forum.beagleboard.org/t/bb-org-debian-buster-iot-v4-19-conf-build-failing-on-bone101-install-cloud9-permissions/33597 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-bone-spi1-0-overlay-development-and-debug/34113 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-building-tensorflow-lite-custom-model-artifacts-for-libtidl-tfl-delegate/37861/6 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942?page=2#post_29 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942?page=3 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942?page=2#post_24 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942?page=2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942/24 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942/29 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-cortex-r5-gpio-toggle-experiment/32942/30 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474#beaglebone-ai-64-boot-sequence-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474#microsd-nothing-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474#post_2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474#ti-j721e_evm-boot-sequence-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474/2#ti-j721e_evm-boot-sequence-1 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474/2#microsd-nothing-3 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474/2#beaglebone-ai-64-boot-sequence-2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-i2c-1-and-i2c-5-not-working/32488/8 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-pinmux-spreedsheet/32418 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-pinmux-spreedsheet/32418/5 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-pinmux-spreedsheet/32418/6 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-rpi-display-7-inch-dsi/33178 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-stuck-in-boot-prompt-or-loop/35147/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64-xbee-adapter/33076/2 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64/36217#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64/36217 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-64/36217/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-and-sd-card-booting-and-two-penguins/33116/4 (0 characters)
# Fetched https://forum.beagleboard.org/t/bbai-lcd-cape-and-bbbl-cape-compatibility/1793 (0 characters)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 37
#      34     print("Thread contents saved to threads_content.json")
#      36 # Example usage:
# ---> 37 fetch_thread_content(sorted_links)
#
# Cell In[14], line 16, in fetch_thread_content(thread_urls, delay)
#      13     threads_content[base_url] = []
#      15 try:
# ---> 16     response = requests.get(thread_url, timeout=10)
#      17     soup = BeautifulSoup(response.text, 'html.parser')
#      18     # Extract main post content (Discourse: <div class="cooked">)
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/gsoc/rag_poc/myenv/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
import random

# Example: Using a session, custom headers, and random delays
def fetch_thread_content_polite(thread_urls, min_delay=0.5, max_delay=2.0):
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    })
    threads_content = {}
    for thread_url in thread_urls:
        base_url = thread_url.rsplit('/', 1)[0] if thread_url.rsplit('/', 1)[-1].isdigit() else thread_url
        if base_url not in threads_content:
            threads_content[base_url] = []
        try:
            response = session.get(thread_url, timeout=10)
            soup = BeautifulSoup(response.text, 'html.parser')
            cooked = soup.find('div', class_='cooked')
            text = cooked.get_text(separator='\n', strip=True) if cooked else ''
            print(f"Fetched {thread_url} ({len(text)} characters)")
            threads_content[base_url].append(text)
        except Exception as e:
            print(f"Failed to fetch {thread_url}: {e}")
        time.sleep(random.uniform(min_delay, max_delay))  # Random polite delay
    threads_content_joined = {url: '\n'.join(filter(None, replies)) for url, replies in threads_content.items()}
    with open('threads_content_polite.json', 'w', encoding='utf-8') as jf:
        json.dump(threads_content_joined, jf, ensure_ascii=False, indent=2)
    print("Thread contents saved to threads_content_polite.json")

# Example usage:
fetch_thread_content_polite(sorted_links)
# Out:
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/0x400-arch1/40344/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318/49 (0 characters)
# Fetched https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318/49 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134#post_3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134/3 (0 characters)
# Fetched https://forum.beagleboard.org/t/2025-gsoc-repositories/42207 (0 characters)
# Fetched https://forum.beagleboard.org/t/2025-gsoc-repositories/42207 (0 characters)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 30
#      27     print("Thread contents saved to threads_content_polite.json")
#      29 # Example usage:
# ---> 30 fetch_thread_content_polite(sorted_links)
#
# Cell In[15], line 23, in fetch_thread_content_polite(thread_urls, min_delay, max_delay)
#      21     except Exception as e:
#      22         print(f"Failed to fetch {thread_url}: {e}")
# ---> 23     time.sleep(random.uniform(min_delay, max_delay))  # Random polite delay
#      24 threads_content_joined = {url: '\n'.join(filter(None, replies)) for url, replies in threads_content.items()}
#      25 with open('threads_content_polite.json', 'w', encoding='utf-8') as jf:
#
# KeyboardInterrupt:

# %%
# Debugging cell: Check what is being returned by the forum
if sorted_links:
    test_url = sorted_links[0]
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    })
    response = session.get(test_url, timeout=10)
    print(f"Status code: {response.status_code}")
    print("First 500 characters of response:")
    print(response.text[:500])
    soup = BeautifulSoup(response.text, 'html.parser')
    cooked = soup.find('div', class_='cooked')
    print(f"cooked: {cooked}")
else:
    print("sorted_links is empty!")
# Out:
# Status code: 200
# First 500 characters of response:
# <!DOCTYPE html>
# <html lang="en" class="desktop-view not-mobile-device text-size-normal anon">
#   <head>
#     <meta charset="utf-8">
#     <title>0x400(arch1) - General Discussion - BeagleBoard</title>
#     <meta name="description" content="Hi all,
# my kernel version is :
# /opt/scripts/tools# ./version.sh
# git:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]
# eeprom:[A335BNLT00C02208SBB16124]
# model:[TI_AM335x_BeagleBone_Black]
# dogtag:[BeagleBoard.&amp;hellip;">
#     <meta name="discourse_them
# cooked: None

# %%
# Print all div classes and a larger HTML snippet to help identify the post content container
if sorted_links:
    test_url = sorted_links[0]
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    })
    response = session.get(test_url, timeout=10)
    soup = BeautifulSoup(response.text, 'html.parser')
    print("First 1000 characters of HTML:")
    print(response.text)
    print("\nAll div classes on the page:")
    divs = soup.find_all('div')
    classes = set()
    for div in divs:
        if 'class' in div.attrs:
            classes.update(div['class'])
    print(classes)
else:
    print("sorted_links is empty!")
# Out:
# First 1000 characters of HTML:
# <!DOCTYPE html>
# <html lang="en" class="desktop-view not-mobile-device text-size-normal anon">
#   <head>
#     <meta charset="utf-8">
#     <title>0x400(arch1) - General Discussion - BeagleBoard</title>
#     <meta name="description" content="Hi all,
# my kernel version is :
# /opt/scripts/tools# ./version.sh
# git:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]
# eeprom:[A335BNLT00C02208SBB16124]
# model:[TI_AM335x_BeagleBone_Black]
# dogtag:[BeagleBoard.&amp;hellip;">
#     <meta name="discourse_theme_id" content="1">
#     <meta name="discourse_current_homepage" content="categories">
#
#     <meta name="generator" content="Discourse 3.4.1 - https://github.com/discourse/discourse version 909b93f40f92f44757493e67accf65e2181469bd">
# <link rel="icon" type="image/png" href="https://forum.beagleboard.org/uploads/default/optimized/2X/f/f5301a304d5f6ecc82ed0f196c1eb3eec34108b6_2_32x32.png">
# <link rel="apple-touch-icon" type="image/png" href="https://forum.beagleboard.org/uploads/default/optimized/2X/e/eb85adde2459145e0137d1a802fe9d47a876ce95_2_180x180.png">
# <meta name="theme-color" media="all" content="#fff">
#
# <meta name="color-scheme" content="light">
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, viewport-fit=cover">
# <link rel="canonical" href="https://forum.beagleboard.org/t/0x400-arch1/40344" />
#
# <link rel="search" type="application/opensearchdescription+xml" href="https://forum.beagleboard.org/opensearch.xml" title="BeagleBoard Search">
#
#
#
#       <meta name="fragment" content="!">
#
#
#
#
#     <link rel="preload" href="/assets/start-discourse-9f921142b762fb91207051d0a28e571b9455bab74e7d0e03726024c286cff8d5.js" as="script" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd">
#     <link rel="preload" href="/assets/browser-update-5faeb6403cf1359d9e201f096cc21a2cb3290010f06dac44d3d9c52210a05aac.js" as="script" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd">
#
#     <script defer src="/assets/browser-detect-06b8e45041d4587c0c6b454b2c35e1584b6ab99cf1792f325e4ff851f4db507d.js" data-discourse-entrypoint="browser-detect" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#     <script defer src="/assets/vendor.9a425c33fe025cd82b2ebcdb87489d36-345488c3d0afb400bd76f141cd80982fe7b30fb0f12cdcedc1bb5522b3982681.js" data-discourse-entrypoint="vendor" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#     <script defer src="/assets/chunk.c34a86af0fd4cb24f720.d41d8cd9.js" data-discourse-entrypoint="discourse" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
# <script defer src="/assets/chunk.fb321f935373b67ec9b2.d41d8cd9.js" data-discourse-entrypoint="discourse" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/chat-1df14417928e9834276249162d23962920a0d8a5035f1697b377995690c91735.js" data-discourse-entrypoint="plugins/chat" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/chat_admin-eab0514052859de98d1b5e496e7afe4c2a9beb15e48c6821575999b9094eacc0.js" data-discourse-entrypoint="plugins/chat_admin" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/checklist-59d4201f372292bf411ce80e8b30eab517f35b741a7f067353bb3d6ae75bf84d.js" data-discourse-entrypoint="plugins/checklist" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-calendar-06da183bd7813bbb421eef7cc5ccc383810786e8bd5f911b971a13b628a76788.js" data-discourse-entrypoint="plugins/discourse-calendar" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-chat-integration-5e467437240a54fab248002428ea572a6bb746e57eb93f3f88635f5faa6fc009.js" data-discourse-entrypoint="plugins/discourse-chat-integration" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-chat-integration_admin-67c39266732f5154b03723530cbb4d671e58955686940cc9d881aa151d35e782.js" data-discourse-entrypoint="plugins/discourse-chat-integration_admin" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-data-explorer-b5f6b80b1a0688ed2eaf2745e15ce469386f064e35ce1f1280d00540626deb2f.js" data-discourse-entrypoint="plugins/discourse-data-explorer" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-details-a19980264e3a6feb20b7e320b03ab0e7a3457105d99b863cd2f62eda09f15507.js" data-discourse-entrypoint="plugins/discourse-details" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-lazy-videos-9aedaec9b360053ab6f08fc1906a26d134f2c3c18220cd09a96549a2067584fb.js" data-discourse-entrypoint="plugins/discourse-lazy-videos" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-local-dates-6681376eddaeaa92ab79f843fefeac50b6c52e3130b6c243961cb94964f74da6.js" data-discourse-entrypoint="plugins/discourse-local-dates" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-presence-f6add9a464299b074ae7a11ae7ccaab8d4f3595332a2fd1c1c2228ac2fdf3ef5.js" data-discourse-entrypoint="plugins/discourse-presence" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-solved-98c5a0378a4666b9a3ade2df9b7f88b74f7b1e3950c7cf6670e2f811a95fefc7.js" data-discourse-entrypoint="plugins/discourse-solved" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/discourse-voting-80dbe1be6c67825dfd5e1d57f1da50c9f6c3907667f3719345b48d8fbb747945.js" data-discourse-entrypoint="plugins/discourse-voting" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/docker_manager_admin-b61fe75b0df3ec0b77a671b0aa128889c4b007bcb60c9c411d614bcd5198af71.js" data-discourse-entrypoint="plugins/docker_manager_admin" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/footnote-29982de0bf91e537d1c9bf776cf5491314880b6ab7e9809ee2b0ad129af28bbd.js" data-discourse-entrypoint="plugins/footnote" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/footnote_extra-295b457b90cb18fedfdb544868c494c71842a27c0781d3042fa4fd26589204fa.js" data-discourse-entrypoint="plugins/footnote_extra" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/poll-706b6a1af436b4eadb98f0b34cdda1bf54e952b3f394cb3a10c608e3a901bea0.js" data-discourse-entrypoint="plugins/poll" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/assets/plugins/spoiler-alert-f248215b3244c267d8dff2d32901afb6d1dd07988eff90c2b4fc794234956de7.js" data-discourse-entrypoint="plugins/spoiler-alert" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#     <script defer src="/assets/locales/en-00170d2c5b8d3f556626fbd7ee85d28ead724e4048780e8aeacbaec9e93bd375.js" data-discourse-entrypoint="locales/en" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#     <script defer src="/extra-locales/mf?v=50fc7aac4b913b2fb6284a3ad8efa92b"  nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#
#
#       <script defer src="/theme-javascripts/f49c26ee35d4ff943211ec9b579ceea935a2634f.js?__ws=forum.beagleboard.org" data-theme-id="6" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <script defer src="/theme-javascripts/ab931af260743fd50c0621991230979986491590.js?__ws=forum.beagleboard.org" data-theme-id="6" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#       <style>
#   @import url("https://use.typekit.net/tpq8sxk.css");
# </style>
#
#
#     <meta id="data-ga-universal-analytics" data-tracking-code="G-SB0T3M7ZXW" data-json="{&quot;cookieDomain&quot;:&quot;auto&quot;}" data-auto-link-domains="">
#
#   <script async src="https://www.googletagmanager.com/gtag/js?id=G-SB0T3M7ZXW" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#   <script defer src="/assets/google-universal-analytics-v4-e154af4adb3c483a3aba7f9a7229b8881cdc5cf369290923d965a2ad30163ae8.js" data-discourse-entrypoint="google-universal-analytics-v4" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#
#
#     <link id="manifest-link" rel="manifest" href=/manifest.webmanifest crossorigin="use-credentials">
#
#
#         <link rel="alternate nofollow" type="application/rss+xml" title="RSS feed of &#39;0x400(arch1)&#39;" href="https://forum.beagleboard.org/t/0x400-arch1/40344.rss" />
#     <meta property="og:site_name" content="BeagleBoard" />
# <meta property="og:type" content="website" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:image" content="https://forum.beagleboard.org/uploads/default/original/2X/8/81dc5d83c5fbfbe1377be040a695ce030a4792cb.png" />
# <meta property="og:image" content="https://forum.beagleboard.org/uploads/default/original/2X/f/f88b6ddd233f3e7a0354031500455b1d3873dd94.png" />
# <meta property="og:url" content="https://forum.beagleboard.org/t/0x400-arch1/40344" />
# <meta name="twitter:url" content="https://forum.beagleboard.org/t/0x400-arch1/40344" />
# <meta property="og:title" content="0x400(arch1)" />
# <meta name="twitter:title" content="0x400(arch1)" />
# <meta property="og:description" content="Hi all,  my kernel version is :  /opt/scripts/tools# ./version.sh  git:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]  eeprom:[A335BNLT00C02208SBB16124]  model:[TI_AM335x_BeagleBone_Black]  dogtag:[BeagleBoard.org Debian Buster LXQt Image 2020-08-25]  bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot SPL 2019.04-00002-gc9b3922522 (Aug 24 2020 - 16:42:18 -0500)]:[location: dd MBR]  bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot 2019.04-00002-gc9b3922522]:[location: dd..." />
# <meta name="twitter:description" content="Hi all,  my kernel version is :  /opt/scripts/tools# ./version.sh  git:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]  eeprom:[A335BNLT00C02208SBB16124]  model:[TI_AM335x_BeagleBone_Black]  dogtag:[BeagleBoard.org Debian Buster LXQt Image 2020-08-25]  bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot SPL 2019.04-00002-gc9b3922522 (Aug 24 2020 - 16:42:18 -0500)]:[location: dd MBR]  bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot 2019.04-00002-gc9b3922522]:[location: dd..." />
# <meta property="og:article:section" content="General Discussion" />
# <meta property="og:article:section:color" content="231F20" />
# <meta property="og:article:tag" content="beaglebone-black" />
# <meta property="article:published_time" content="2024-11-22T14:13:47+00:00" />
# <meta property="og:ignore_canonical" content="true" />
#
#
#
#     <script type="application/ld+json">{"@context":"http://schema.org","@type":"QAPage","name":"0x400(arch1)","mainEntity":{"@type":"Question","name":"0x400(arch1)","text":"Hi all,\n\nmy kernel version is :\n\n/opt/scripts/tools# ./version.sh\n\ngit:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]\n\neeprom:[A335BNLT00C02208SBB16124]\n\nmodel:[TI_AM335x_BeagleBone_Black]\n\ndogtag:[<a href=\"http://BeagleBoard.org\" rel=\"noopener nofollow ugc\">BeagleBoard.org<\/a> Debian Buster LXQt Image 2020-08-25]\n\nbootloader:[microSD-(push-button)]:[/d&hellip;","upvoteCount":0,"answerCount":0,"datePublished":"2024-11-22T14:13:47.526Z","author":{"@type":"Person","name":"malkowki","url":"https://forum.beagleboard.org/u/malkowki"}}}</script>
#
#     <meta id="data-discourse-setup" data-base-url="https://forum.beagleboard.org" data-base-uri="" data-environment="production" data-letter-avatar-version="5_047764fa20c941da5a8a2a620d7322fb" data-service-worker-url="service-worker.js" data-default-locale="en" data-asset-version="ee49624bdc4febed2e2a9c8b076553d5" data-disable-custom-css="false" data-highlight-js-path="/highlight-js/forum.beagleboard.org/600885de53a0c5dcaf15540b83e94aafa44c5313.js" data-svg-sprite-path="/svg-sprite/forum.beagleboard.org/svg-1-86d7cd1452305f181fa3c2789a17daf8ad4ae36e.js" data-enable-js-error-reporting="true" data-color-scheme-is-dark="false" data-user-dark-scheme-id="-1">
#
#     <meta name="discourse/config/environment" content="%7B%22modulePrefix%22%3A%22discourse%22%2C%22environment%22%3A%22production%22%2C%22rootURL%22%3A%22%22%2C%22locationType%22%3A%22history%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22EXTEND_PROTOTYPES%22%3A%7B%22Date%22%3Afalse%2C%22String%22%3Afalse%7D%7D%2C%22APP%22%3A%7B%22name%22%3A%22discourse%22%2C%22version%22%3A%223.4.1%20909b93f40f92f44757493e67accf65e2181469bd%22%7D%7D" />
#   </head>
#
#   <body class="">
#       <section id="d-splash">
#   <style>
#     html {
#       overflow-y: hidden !important;
#     }
#
#     /* user picked a theme where the "regular" scheme is dark */
#       /* user picked a theme a light scheme and also enabled a dark scheme */
#
#       /* deal with light scheme first */
#       @media (prefers-color-scheme: light) {
#         html {
#           background-color: #fff;
#         }
#
#         #d-splash {
#           --dot-color: #08c;
#         }
#       }
#
#       /* then deal with dark scheme */
#       @media (prefers-color-scheme: dark) {
#         html {
#           background-color: #fff;
#         }
#
#         #d-splash {
#           --dot-color: #08c;
#         }
#       }
#
#     #d-splash {
#       display: grid;
#       place-items: center;
#       position: absolute;
#       left: 0;
#       top: 0;
#       width: 100vw;
#       z-index: 1001;
#     }
#
#     #d-splash .preloader-image {
#       --splash-dot-size: max(1vw, 25px);
#       --splash-dot-spacing: calc(var(--splash-dot-size) * 1.5);
#       width: calc((var(--splash-dot-size) + var(--splash-dot-spacing)) * 5);
#       height: 100vh;
#       background-size: cover;
#     }
#
#     @keyframes d-splash-fade-in {
#       0% {
#         opacity: 0;
#       }
#       100% {
#         opacity: 1;
#       }
#     }
#
#     .dots {
#       animation-name: d-splash-loader;
#       animation-timing-function: ease-in-out;
#       animation-duration: 3s;
#       animation-iteration-count: infinite;
#       animation-delay: calc(var(--n) * 0.15s);
#
#       position: absolute;
#       top: calc(50% - var(--splash-dot-size) / 2);
#       left: calc((50% - var(--splash-dot-size) / 2) + (var(--n) * var(--splash-dot-spacing)));
#       transform-origin: calc((var(--splash-dot-spacing) * var(--n) * -1) + var(--splash-dot-size)/2) center;
#
#       width: var(--splash-dot-size);
#       height: var(--splash-dot-size);
#       border-radius: 50%;
#
#       background-color: var(--dot-color);
#       filter: saturate(2) opacity(0.85);
#       opacity: 0;
#     }
#
#     @keyframes d-splash-loader {
#       0% {
#         opacity: 0;
#         transform: scale(1);
#       }
#       45% {
#         opacity: 1;
#         transform: scale(0.7);
#       }
#       65% {
#         opacity: 1;
#         transform: scale(0.7);
#       }
#       100% {
#         opacity: 0;
#         transform: scale(1);
#       }
#     }
#   </style>
#
#   <div class="preloader-image" elementtiming="discourse-splash-visible">
#     <div class="dots" style="--n:-2;"></div>
#     <div class="dots" style="--n:-1;"></div>
#     <div class="dots" style="--n:0;"></div>
#     <div class="dots" style="--n:1;"></div>
#     <div class="dots" style="--n:2;"></div>
#   </div>
#   <script nonce="5L7TZNqklpzcxzP6t2Nd3YAAd">
#     const svg = `<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1"><!-- LCP candidate image ${".".repeat(5000)} --></svg>`;
#     document.querySelector("#d-splash .preloader-image").style.backgroundImage = `url('data:image/svg+xml,${svg}')`
#   </script>
#
#   <noscript>
#     <style>
#       html {
#         overflow-y: revert !important;
#       }
#
#       #d-splash {
#         display: none;
#       }
#     </style>
#   </noscript>
# </section>
#
#
#     <discourse-assets>
#       <discourse-assets-stylesheets>
#         <link href="/stylesheets/color_definitions_base__1_15c33dfcbf5fe5c6c3f345ece0e4e6156ad64e1c.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" class="light-scheme"/>
#
#   <link href="/stylesheets/desktop_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="desktop"  />
#
#
#
#   <link href="/stylesheets/chat_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="chat"  />
#   <link href="/stylesheets/checklist_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="checklist"  />
#   <link href="/stylesheets/discourse-calendar_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-calendar"  />
#   <link href="/stylesheets/discourse-chat-integration_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-chat-integration"  />
#   <link href="/stylesheets/discourse-data-explorer_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-data-explorer"  />
#   <link href="/stylesheets/discourse-details_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-details"  />
#   <link href="/stylesheets/discourse-lazy-videos_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-lazy-videos"  />
#   <link href="/stylesheets/discourse-local-dates_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-local-dates"  />
#   <link href="/stylesheets/discourse-narrative-bot_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-narrative-bot"  />
#   <link href="/stylesheets/discourse-presence_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-presence"  />
#   <link href="/stylesheets/discourse-solved_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-solved"  />
#   <link href="/stylesheets/discourse-voting_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-voting"  />
#   <link href="/stylesheets/docker_manager_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="docker_manager"  />
#   <link href="/stylesheets/footnote_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="footnote"  />
#   <link href="/stylesheets/poll_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="poll"  />
#   <link href="/stylesheets/spoiler-alert_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="spoiler-alert"  />
#   <link href="/stylesheets/chat_desktop_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="chat_desktop"  />
#   <link href="/stylesheets/discourse-calendar_desktop_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-calendar_desktop"  />
#   <link href="/stylesheets/discourse-voting_desktop_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="discourse-voting_desktop"  />
#   <link href="/stylesheets/poll_desktop_467d5a0d87b75ad72981cab2ed851bf393b6474f.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="poll_desktop"  />
#
#   <link href="/stylesheets/desktop_theme_6_77b12665ae23fdc17381329972ba481fed6a59c0.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="desktop_theme" data-theme-id="6" data-theme-name="discotoc"/>
# <link href="/stylesheets/desktop_theme_1_c7be34476592d7cafe14b0e0d0f32dd36342aba4.css?__ws=forum.beagleboard.org" media="all" rel="stylesheet" data-target="desktop_theme" data-theme-id="1" data-theme-name="default"/>
#
#       </discourse-assets-stylesheets>
#       <discourse-assets-json>
#         <div class="hidden" id="data-preloaded" data-preloaded="{&quot;topic_40344&quot;:&quot;{\&quot;post_stream\&quot;:{\&quot;posts\&quot;:[{\&quot;id\&quot;:159408,\&quot;name\&quot;:\&quot;Beninio Mbila\&quot;,\&quot;username\&quot;:\&quot;malkowki\&quot;,\&quot;avatar_template\&quot;:\&quot;/user_avatar/forum.beagleboard.org/malkowki/{size}/2907_2.png\&quot;,\&quot;created_at\&quot;:\&quot;2024-11-22T14:13:47.777Z\&quot;,\&quot;cooked\&quot;:\&quot;\\u003cp\\u003eHi all,\\u003cbr\\u003e\\nmy kernel version is :\\u003cbr\\u003e\\n/opt/scripts/tools# ./version.sh\\u003cbr\\u003e\\ngit:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]\\u003cbr\\u003e\\neeprom:[A335BNLT00C02208SBB16124]\\u003cbr\\u003e\\nmodel:[TI_AM335x_BeagleBone_Black]\\u003cbr\\u003e\\ndogtag:[\\u003ca href=\\\&quot;http://BeagleBoard.org\\\&quot; rel=\\\&quot;noopener nofollow ugc\\\&quot;\\u003eBeagleBoard.org\\u003c/a\\u003e Debian Buster LXQt Image 2020-08-25]\\u003cbr\\u003e\\nbootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot SPL 2019.04-00002-gc9b3922522 (Aug 24 2020 - 16:42:18 -0500)]:[location: dd MBR]\\u003cbr\\u003e\\nbootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot 2019.04-00002-gc9b3922522]:[location: dd MBR]\\u003cbr\\u003e\\nUBOOT: Booted Device-Tree:[am335x-boneblack-uboot-univ.dts]\\u003cbr\\u003e\\nUBOOT: Loaded Overlay:[AM335X-PRU-UIO-00A0]\\u003cbr\\u003e\\nUBOOT: Loaded Overlay:[BB-ADC-00A0.bb.org-overlays]\\u003cbr\\u003e\\nkernel:[4.19.94-ti-r50]\\u003cbr\\u003e\\nnodejs:[v10.24.0]\\u003cbr\\u003e\\n/boot/uEnv.txt Settings:\\u003cbr\\u003e\\nuboot_overlay_options:[enable_uboot_overlays=1]\\u003cbr\\u003e\\nuboot_overlay_options:[disable_uboot_overlay_emmc=1]\\u003cbr\\u003e\\nuboot_overlay_options:[disable_uboot_overlay_video=1]\\u003cbr\\u003e\\nuboot_overlay_options:[disable_uboot_overlay_audio=1]\\u003cbr\\u003e\\nuboot_overlay_options:[disable_uboot_overlay_wireless=1]\\u003cbr\\u003e\\nuboot_overlay_options:[uboot_overlay_pru=/lib/firmware/AM335X-PRU-UIO-00A0.dtbo]\\u003cbr\\u003e\\nuboot_overlay_options:[enable_uboot_cape_universal=1]\\u003cbr\\u003e\\npkg check: to individually upgrade run: [sudo apt install --only-upgrade ]\\u003cbr\\u003e\\npkg:[bb-cape-overlays]:[4.14.20210821.0-0~buster+20210821]\\u003cbr\\u003e\\npkg:[bb-customizations]:[1.20240119.0-0~buster+20240119]\\u003cbr\\u003e\\npkg:[bb-usb-gadgets]:[1.20230414.0-0~buster+20230414]\\u003cbr\\u003e\\npkg:[bb-wl18xx-firmware]:[1.20230414.0-0~buster+20230414]\\u003cbr\\u003e\\npkg:[kmod]:[26-1]\\u003cbr\\u003e\\npkg:[librobotcontrol]:[1.0.5-git20200715.0-0~buster+20200716]\\u003cbr\\u003e\\npkg:[firmware-ti-connectivity]:[20190717-2rcnee1~buster+20200305]\\u003cbr\\u003e\\ngroups:[debian : debian adm kmem dialout cdrom floppy audio dip video plugdev users systemd-journal input bluetooth netdev i2c gpio admin spi iio docker tisdk weston-launch xenomai cloud9ide pwm eqep remoteproc]\\u003cbr\\u003e\\ncmdline:[console=ttyO0,115200n8 bone_capemgr.uboot_capemgr_enabled=1 root=/dev/mmcblk0p1 ro rootfstype=ext4 rootwait coherent_pool=1M net.ifnames=0 lpj=1990656 rng_core.default_quality=100 quiet]\\u003cbr\\u003e\\ndmesg | grep remote\\u003cbr\\u003e\\n[14880114.028310] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev\\u003cbr\\u003e\\n[14880114.067577] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether\\u003c/p\\u003e\\n\\u003cpre\\u003e\\u003ccode class=\\\&quot;lang-auto\\\&quot;\\u003elibcomposite uio_pdrv_genirq uio appletalk ax25 spidev\\n[14880114.106846] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev\\n[14 ...
#       </discourse-assets-json>
#       <discourse-assets-icons></discourse-assets-icons>
#     </discourse-assets>
#
#
#
#
#     <noscript data-path="/t/0x400-arch1/40344">
#
#         <header>
#   <a href="/">
#     BeagleBoard
#   </a>
# </header>
#
#
#         <div id="main-outlet" class="wrap" role="main">
#           <!-- preload-content: -->
#             <div id="topic-title">
#     <h1>
#       <a href="/t/0x400-arch1/40344">0x400(arch1)</a>
#     </h1>
#
#       <div class="topic-category" itemscope itemtype="http://schema.org/BreadcrumbList">
#           <span itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem">
#             <a href="/c/general/8" class="badge-wrapper bullet" itemprop="item">
#               <span class='badge-category-bg' style='background-color: #231F20'></span>
#               <span class='badge-category clear-badge'>
#                 <span class='category-name' itemprop='name'>General Discussion</span>
#               </span>
#             </a>
#             <meta itemprop="position" content="1" />
#           </span>
#       </div>
#
#       <div class="topic-category">
#         <div class='discourse-tags list-tags'>
#             <a href='https://forum.beagleboard.org/tag/beaglebone-black' class='discourse-tag' rel="tag">beaglebone-black</a>
#         </div>
#       </div>
#   </div>
#
#
#
#     <div itemscope itemtype='http://schema.org/DiscussionForumPosting'>
#       <meta itemprop='headline' content='0x400(arch1)'>
#       <link itemprop='url' href='https://forum.beagleboard.org/t/0x400-arch1/40344'>
#       <meta itemprop='datePublished' content='2024-11-22T14:13:47Z'>
#         <meta itemprop='articleSection' content='General Discussion'>
#       <meta itemprop='keywords' content='beaglebone-black'>
#       <div itemprop='publisher' itemscope itemtype="http://schema.org/Organization">
#         <meta itemprop='name' content='BeagleBoard.org Foundation'>
#           <div itemprop='logo' itemscope itemtype="http://schema.org/ImageObject">
#             <meta itemprop='url' content='https://forum.beagleboard.org/uploads/default/original/2X/1/1c02eb18d18b99f211a17ee0ff33405db207e1a9.svg'>
#           </div>
#       </div>
#
#
#           <div id='post_1'  class='topic-body crawler-post'>
#             <div class='crawler-post-meta'>
#               <span class="creator" itemprop="author" itemscope itemtype="http://schema.org/Person">
#                 <a itemprop="url" rel='nofollow' href='https://forum.beagleboard.org/u/malkowki'><span itemprop='name'>malkowki</span></a>
#
#               </span>
#
#                 <link itemprop="mainEntityOfPage" href="https://forum.beagleboard.org/t/0x400-arch1/40344">
#
#
#               <span class="crawler-post-infos">
#                   <time  datetime='2024-11-22T14:13:47Z' class='post-time'>
#                     November 22, 2024,  2:13pm
#                   </time>
#                   <meta itemprop='dateModified' content='2024-11-22T14:13:47Z'>
#               <span itemprop='position'>1</span>
#               </span>
#             </div>
#             <div class='post' itemprop='text'>
#               <p>Hi all,<br>
# my kernel version is :<br>
# /opt/scripts/tools# ./version.sh<br>
# git:/opt/scripts/:[674bb55e34e94e3837f4f55790c7d1a52c9e149f]<br>
# eeprom:[A335BNLT00C02208SBB16124]<br>
# model:[TI_AM335x_BeagleBone_Black]<br>
# dogtag:[<a href="http://BeagleBoard.org" rel="noopener nofollow ugc">BeagleBoard.org</a> Debian Buster LXQt Image 2020-08-25]<br>
# bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot SPL 2019.04-00002-gc9b3922522 (Aug 24 2020 - 16:42:18 -0500)]:[location: dd MBR]<br>
# bootloader:[microSD-(push-button)]:[/dev/mmcblk0]:[U-Boot 2019.04-00002-gc9b3922522]:[location: dd MBR]<br>
# UBOOT: Booted Device-Tree:[am335x-boneblack-uboot-univ.dts]<br>
# UBOOT: Loaded Overlay:[AM335X-PRU-UIO-00A0]<br>
# UBOOT: Loaded Overlay:[BB-ADC-00A0.bb.org-overlays]<br>
# kernel:[4.19.94-ti-r50]<br>
# nodejs:[v10.24.0]<br>
# /boot/uEnv.txt Settings:<br>
# uboot_overlay_options:[enable_uboot_overlays=1]<br>
# uboot_overlay_options:[disable_uboot_overlay_emmc=1]<br>
# uboot_overlay_options:[disable_uboot_overlay_video=1]<br>
# uboot_overlay_options:[disable_uboot_overlay_audio=1]<br>
# uboot_overlay_options:[disable_uboot_overlay_wireless=1]<br>
# uboot_overlay_options:[uboot_overlay_pru=/lib/firmware/AM335X-PRU-UIO-00A0.dtbo]<br>
# uboot_overlay_options:[enable_uboot_cape_universal=1]<br>
# pkg check: to individually upgrade run: [sudo apt install --only-upgrade ]<br>
# pkg:[bb-cape-overlays]:[4.14.20210821.0-0~buster+20210821]<br>
# pkg:[bb-customizations]:[1.20240119.0-0~buster+20240119]<br>
# pkg:[bb-usb-gadgets]:[1.20230414.0-0~buster+20230414]<br>
# pkg:[bb-wl18xx-firmware]:[1.20230414.0-0~buster+20230414]<br>
# pkg:[kmod]:[26-1]<br>
# pkg:[librobotcontrol]:[1.0.5-git20200715.0-0~buster+20200716]<br>
# pkg:[firmware-ti-connectivity]:[20190717-2rcnee1~buster+20200305]<br>
# groups:[debian : debian adm kmem dialout cdrom floppy audio dip video plugdev users systemd-journal input bluetooth netdev i2c gpio admin spi iio docker tisdk weston-launch xenomai cloud9ide pwm eqep remoteproc]<br>
# cmdline:[console=ttyO0,115200n8 bone_capemgr.uboot_capemgr_enabled=1 root=/dev/mmcblk0p1 ro rootfstype=ext4 rootwait coherent_pool=1M net.ifnames=0 lpj=1990656 rng_core.default_quality=100 quiet]<br>
# dmesg | grep remote<br>
# [14880114.028310] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev<br>
# [14880114.067577] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether</p>
# <pre><code class="lang-auto">libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.106846] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.146114] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.185383] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.224655] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.263926] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.303196] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# [14880114.342467] Modules linked in: pm33xx wkup_m3_ipc wkup_m3_rproc remoteproc virtio virtio_ring uio_pruss usb_f_acm u_serial usb_f_ncm usb_f_mass_storage usb_f_rndis u_ether libcomposite uio_pdrv_genirq uio appletalk ax25 spidev
# </code></pre>
# <p>And I am having everytime a flags:<br>
# [  +0.000008] BUG: Bad page state in process rs:main Q:Reg  pfn:96ea3<br>
# [  +0.006556] page:dfc99eec count:0 mapcount:0 mapping:00000000 index:0x1<br>
# [  +0.006906] flags: 0x400(arch_1)<br>
# [  +0.003508] raw: 00000400 00000100 00000200 00000000 00000001 00000000 ffffffff 00000000<br>
# [  +0.008387] raw: 00000000<br>
# [  +0.002891] page dumped because: PAGE_FLAGS_CHECK_AT_PREP flag set<br>
# [  +0.006466] bad because of flags: 0x400(arch_1)</p>
# <p>What could be the issue?</p>
#             </div>
#
#             <div itemprop="interactionStatistic" itemscope itemtype="http://schema.org/InteractionCounter">
#               <meta itemprop="interactionType" content="http://schema.org/LikeAction"/>
#               <meta itemprop="userInteractionCount" content="0" />
#               <span class='post-likes'></span>
#             </div>
#
#           </div>
#           <div id='post_2' itemprop='comment' itemscope itemtype='http://schema.org/Comment' class='topic-body crawler-post'>
#             <div class='crawler-post-meta'>
#               <span class="creator" itemprop="author" itemscope itemtype="http://schema.org/Person">
#                 <a itemprop="url" rel='nofollow' href='https://forum.beagleboard.org/u/malkowki'><span itemprop='name'>malkowki</span></a>
#
#               </span>
#
#
#
#               <span class="crawler-post-infos">
#                   <time itemprop='datePublished' datetime='2024-11-26T14:21:56Z' class='post-time'>
#                     November 26, 2024,  2:21pm
#                   </time>
#                   <meta itemprop='dateModified' content='2024-11-26T14:21:56Z'>
#               <span itemprop='position'>2</span>
#               </span>
#             </div>
#             <div class='post' itemprop='text'>
#               <p>I am still having issue with my Kernel,<br>
# Is there anyone who may help??</p>
# <p><a class="attachment" href="/uploads/short-url/qLJUjHl2I3YTDrxjwlP0sLQZVNR.txt">version.txt</a> (25,2 Ko)<br>
# <a class="attachment" href="/uploads/short-url/4FbeGexrSI8k4bI8Eh8Nau7O05x.txt">dmesg.txt</a> (123,9 Ko)</p>
# <p>D</p>
#             </div>
#
#             <div itemprop="interactionStatistic" itemscope itemtype="http://schema.org/InteractionCounter">
#               <meta itemprop="interactionType" content="http://schema.org/LikeAction"/>
#               <meta itemprop="userInteractionCount" content="0" />
#               <span class='post-likes'></span>
#             </div>
#
#           </div>
#           <div id='post_3' itemprop='comment' itemscope itemtype='http://schema.org/Comment' class='topic-body crawler-post'>
#             <div class='crawler-post-meta'>
#               <span class="creator" itemprop="author" itemscope itemtype="http://schema.org/Person">
#                 <a itemprop="url" rel='nofollow' href='https://forum.beagleboard.org/u/amf99'><span itemprop='name'>amf99</span></a>
#
#               </span>
#
#
#
#               <span class="crawler-post-infos">
#                   <time itemprop='datePublished' datetime='2024-11-26T21:02:22Z' class='post-time'>
#                     November 26, 2024,  9:02pm
#                   </time>
#                   <meta itemprop='dateModified' content='2024-11-26T21:02:22Z'>
#               <span itemprop='position'>3</span>
#               </span>
#             </div>
#             <div class='post' itemprop='text'>
#               <p>is your hart set on using such an old image ??<br>
# there is a 2023 image, can you try that and see if you get the same issues</p><aside class="quote quote-modified" data-post="1" data-topic="31203">
#   <div class="title">
#     <div class="quote-controls"></div>
#     <img loading="lazy" alt="" width="24" height="24" src="https://forum.beagleboard.org/user_avatar/forum.beagleboard.org/robertcnelson/48/2085_2.png" class="avatar">
#     <a href="https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshot-2023-07-01-final/31203">Debian 10.x (Buster) - Monthly Snapshot - 2023-07-01 - (FINAL)</a> <a class="badge-category__wrapper " href="/c/faq/19"><span data-category-id="19" style="--category-badge-color: #0088CC; --category-badge-text-color: #FFFFFF;" data-drop-close="true" class="badge-category " title="This category is intended to help make Frequently Asked Question guides (FAQs) easier to find. Posts in this category can only be made by specifically approved authors and responses should be made in the General Discussion category. Each FAQ should be a wiki and address frequently asked questions around a specific commonly used tag."><span class="badge-category__name">FAQ</span></span></a>
#   </div>
#   <blockquote>
#     <a href="https://wiki.debian.org/DebianBuster" rel="noopener nofollow ugc">DebianBuster</a>
# All these example Snapshots can be written to a microSD with: <a href="https://www.balena.io/etcher/" rel="noopener nofollow ugc">balenaEtcher</a>
#
#
#
#
# Architecture
# Compatible Devices
#
#
#
#
# AM335x
# BeagleBone, BeagleBone Black, BeagleBone Black Wireless, PocketBeagle
#
#
# AM335x
# BeagleBone Blue, BeagleBone Green, BeagleBone Green Wireless,
#
#
# AM57xx
# BeagleBoard-x15, BeagleBone AI
#
#
#
#
#
#
#
# Image
# Expected Outcome with microSD installed in device
#
#
#
#
# microSD
# boot to user console or desktop
#
#
# eMMC
# Device will start an automatic eMMC Flashing procedure, user shoul…
#   </blockquote>
# </aside>
#
#             </div>
#
#             <div itemprop="interactionStatistic" itemscope itemtype="http://schema.org/InteractionCounter">
#               <meta itemprop="interactionType" content="http://schema.org/LikeAction"/>
#               <meta itemprop="userInteractionCount" content="0" />
#               <span class='post-likes'></span>
#             </div>
#
#           </div>
#           <div id='post_4' itemprop='comment' itemscope itemtype='http://schema.org/Comment' class='topic-body crawler-post'>
#             <div class='crawler-post-meta'>
#               <span class="creator" itemprop="author" itemscope itemtype="http://schema.org/Person">
#                 <a itemprop="url" rel='nofollow' href='https://forum.beagleboard.org/u/malkowki'><span itemprop='name'>malkowki</span></a>
#
#               </span>
#
#
#
#               <span class="crawler-post-infos">
#                   <time itemprop='datePublished' datetime='2024-11-27T09:10:50Z' class='post-time'>
#                     November 27, 2024,  9:10am
#                   </time>
#                   <meta itemprop='dateModified' content='2024-11-27T09:10:50Z'>
#               <span itemprop='position'>4</span>
#               </span>
#             </div>
#             <div class='post' itemprop='text'>
#               <p>Hi amf99,<br>
# thanks for your advise. Yes I know that is an old debian kernel I am using since years until I face those issues described in my files. I will need to install all modules for NI-USB visa and of course drivers for uio pruss. we are using this instead of remoteproc because we had already some api that could build and generate pattern and this was done with uio pruss.<br>
# I was hoping to solve this issue keeping the same kernel but you are maybe right to jumb to new image. is this image having Cloud9 installed?</p>
#             </div>
#
#             <div itemprop="interactionStatistic" itemscope itemtype="http://schema.org/InteractionCounter">
#               <meta itemprop="interactionType" content="http://schema.org/LikeAction"/>
#               <meta itemprop="userInteractionCount" content="0" />
#               <span class='post-likes'></span>
#             </div>
#
#           </div>
#           <div id='post_5' itemprop='comment' itemscope itemtype='http://schema.org/Comment' class='topic-body crawler-post'>
#             <div class='crawler-post-meta'>
#               <span class="creator" itemprop="author" itemscope itemtype="http://schema.org/Person">
#                 <a itemprop="url" rel='nofollow' href='https://forum.beagleboard.org/u/foxsquirrel'><span itemprop='name'>foxsquirrel</span></a>
#
#               </span>
#
#
#
#               <span class="crawler-post-infos">
#                   <time itemprop='datePublished' datetime='2024-11-27T15:52:30Z' class='post-time'>
#                     November 27, 2024,  3:52pm
#                   </time>
#                   <meta itemprop='dateModified' content='2024-11-27T15:52:30Z'>
#               <span itemprop='position'>5</span>
#               </span>
#             </div>
#             <div class='post' itemprop='text'>
#               <aside class="quote no-group" data-username="malkowki" data-post="1" data-topic="40344">
# <div class="title">
# <div class="quote-controls"></div>
# <img loading="lazy" alt="" width="24" height="24" src="https://forum.beagleboard.org/user_avatar/forum.beagleboard.org/malkowki/48/2907_2.png" class="avatar"> malkowki:</div>
# <blockquote>
# <p>[ +0.000008] BUG: Bad page state in process rs:main Q:Reg pfn:96ea3<br>
# [ +0.006556] page:dfc99eec count:0 mapcount:0 mapping:00000000 index:0x1<br>
# [ +0.006906] flags: 0x400(arch_1)<br>
# [ +0.003508] raw: 00000400 00000100 00000200 00000000 00000001 00000000 ffffffff 00000000<br>
# [ +0.008387] raw: 00000000<br>
# [ +0.002891] page dumped because: PAGE_FLAGS_CHECK_AT_PREP flag set<br>
# [ +0.006466] bad because of flags: 0x400(arch_1)</p>
# </blockquote>
# </aside>
# <p>I don’t have clue about what is going on with your board, this is all conjecture.</p>
# <p>It appears the kernel is having an issue with memory <code>rs:main</code>. Since that is an old kernel I would suspect it has been running perfectly until this point. Hence, might be the ram has an issue. It might have some logs that have now filled up all the emmc??? If you can jump start it on SD card and mount emmc then look around and see if that is filled up. This is just a guess, not having the board and intimate knowledge of the code makes this difficult.</p>
#             </div>
#
#             <div itemprop="interactionStatistic" itemscope itemtype="http://schema.org/InteractionCounter">
#               <meta itemprop="interactionType" content="http://schema.org/LikeAction"/>
#               <meta itemprop="userInteractionCount" content="0" />
#               <span class='post-likes'></span>
#             </div>
#
#           </div>
#     </div>
#
#
#
#
#
#
#
#           <!-- :preload-content -->
#         </div>
#
#         <footer class="container wrap">
#   <nav class='crawler-nav'>
#     <ul>
#       <li itemscope itemtype='http://schema.org/SiteNavigationElement'>
#         <span itemprop='name'>
#           <a href='/' itemprop="url">Home </a>
#         </span>
#       </li>
#       <li itemscope itemtype='http://schema.org/SiteNavigationElement'>
#         <span itemprop='name'>
#           <a href='/categories' itemprop="url">Categories </a>
#         </span>
#       </li>
#       <li itemscope itemtype='http://schema.org/SiteNavigationElement'>
#         <span itemprop='name'>
#           <a href='/guidelines' itemprop="url">Guidelines </a>
#         </span>
#       </li>
#         <li itemscope itemtype='http://schema.org/SiteNavigationElement'>
#           <span itemprop='name'>
#             <a href='/tos' itemprop="url">Terms of Service </a>
#           </span>
#         </li>
#         <li itemscope itemtype='http://schema.org/SiteNavigationElement'>
#           <span itemprop='name'>
#             <a href='/privacy' itemprop="url">Privacy Policy </a>
#           </span>
#         </li>
#     </ul>
#   </nav>
#   <p class='powered-by-link'>Powered by <a href="https://www.discourse.org">Discourse</a>, best viewed with JavaScript enabled</p>
# </footer>
#
#     </noscript>
#
#
#
#
#
#     <section id='main'>
#     </section>
#
#       <form id='hidden-login-form' method="post" action="/login" style="display: none;">
#         <input name="username" type="text"     id="signin_username">
#         <input name="password" type="password" id="signin_password">
#         <input name="redirect" type="hidden">
#         <input type="submit" id="signin-button" value="Log In">
#       </form>
#
#     <script defer src="/assets/start-discourse-9f921142b762fb91207051d0a28e571b9455bab74e7d0e03726024c286cff8d5.js" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#
#     <script defer src="/assets/browser-update-5faeb6403cf1359d9e201f096cc21a2cb3290010f06dac44d3d9c52210a05aac.js" nonce="5L7TZNqklpzcxzP6t2Nd3YAAd"></script>
#
#
#
#
#
#     <script nonce="5L7TZNqklpzcxzP6t2Nd3YAAd">/* Workaround for https://bugs.webkit.org/show_bug.cgi?id=209261 */</script>
#   </body>
# </html>
#
#
# All div classes on the page:
# {'list-tags', 'topic-body', 'crawler-post', 'topic-category', 'title', 'dots', 'preloader-image', 'post', 'wrap', 'quote-controls', 'crawler-post-meta', 'discourse-tags', 'hidden'}

# %%
import requests
from bs4 import BeautifulSoup, Comment
import re

if True:
    test_url = "https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318"
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    })
    response = session.get(test_url, timeout=10)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Remove script, style, and hidden elements
    for tag in soup(['script', 'style']):
        tag.decompose()
    for tag in soup.select('[style*="display:none"], [hidden], .hidden'):
        tag.decompose()

    # Detect usernames from typical Discourse attributes
    username_tags = soup.find_all(attrs={
        'data-user-card': True
    }) + soup.find_all(class_=['username', 'poster', 'creator'])

    usernames = set(tag.get_text(strip=True) for tag in username_tags if tag.get_text(strip=True))

    # Get visible text
    visible_text = soup.get_text(separator='\n', strip=True)

    # Highlight usernames robustly
    def highlight_usernames(line):
        for uname in sorted(usernames, key=len, reverse=True):
            line = re.sub(rf'(?<!\*)\b{re.escape(uname)}\b(?!\*)', f'**{uname}**', line)
        return line

    # Apply highlight to each line
    highlighted_lines = [highlight_usernames(line) for line in visible_text.split('\n') if line.strip()]
    print('\n'.join(highlighted_lines))

else:
    print("sorted_links is empty!")
# Out:
# 192.168.7.2 is NOT opening or reachable - GoogleGroups - BeagleBoard
# BeagleBoard
# 192.168.7.2 is NOT opening or reachable
# GoogleGroups
# **Pankaj_Rai**
# June 26, 2020, 11:59am
# 1
# HI,
# I’m just getting started with the BBB and i’m trying to go to on board server 192.168.7.2 as mentioned in the Getting started doc.
# But the problem is that 192.168.7.2 is not opening or not reachable. While I have interfaced the BBB with mini B cable to laptop(I’m using Ubuntu 18.0.04 in it) and also connected the BBB with ethernet cable to my laptop.
# Please suggest the possible cause and how to debug and make it work.
# thanks
# Pankaj
# **amf99**
# June 26, 2020,  4:00pm
# 2
# What Image are you using?
# cat /etc/dogtag (provided it is a debian image)
# or sudo /opt/scripts/tools/version.sh
# or uname -a (might help)
# How are you powering the board, 5v supply or usb? if usb, is it via a powered hub?
# can you also provide the output of ifconfig from the beaglebone black?
# Does Nautilus show BEAGLEBONE folder?
# I’m running ‘
# BeagleBoard.org
# Debian Image 2019-08-03’ and am able to ssh to the beaglebone black on 7.2 and 6.1 from desktop (ubuntu 18.04)
# **Pankaj_Rai**
# July 12, 2020,  5:44pm
# 3
# Hi amf,
# it’s been a while since I’ve started using BBB. So, I dont know actually how to get started with BBB.
# I haven’t installed any image on BBB on my own. I just followed the steps mentioned in Readme of BBB. (I’ve attached the SS for your reference). Do we need to install any image to BBB first?
# Don’t the BBB comes with the preinstalled OS (or image)?
# kindly guide me through this.
# thanks
# Pankaj
# **Pankaj_Rai**
# July 12, 2020,  6:39pm
# 4
# ssh: connect to host 192.168.7.1 port 22: Connection timed out
# this is what i’m getting as error while connecting BBB to 192.68.7.2
# what could be the reason and how can we resolve this issue.
# thanks
# Pankaj
# **KenUnix**
# July 13, 2020,  5:10pm
# 5
# If you have not modified it’s configuration you should ssh to 196.168.7.2
# 192.168.7.1 is the P.C. side.of the connection.
# When powering the BBB up and connecting the USB cable does the PC play the UP tone?
# **Pankaj_Rai**
# July 13, 2020,  5:13pm
# 6
# Hi,
# Pc does play a sound while connecting BBB to pc. And I’ve not changed any configuration of the BBB.
# Thanks.
# **amf99**
# July 13, 2020,  5:43pm
# 7
# Your using Ubuntu 18.0.04 good, this is what I’m using also. Are you using any firewall software, like ufw, if you are, make sure port 22 is allowed.
# Yes, BBB comes with pre-install OS. If your BBB boots without and sdcard, then it is booting form the emmc.
# to boot from the sdcard, you have to hold the ‘USER’ button during the boot process. (that is from the time the power is applied, till the leds start flickering)
# Do you have a USB-TO-SERIAL converter that can be connected to J1, it may help in debugging the issue.
# Can you ping 192.168.7.2 from your lap top?
# When you ssh, are you using debian or root?
# You do have openssh
# -
# server installed on the laptop, right?
# **jomoengineer**
# July 13, 2020,  5:44pm
# 8
# What image are you running on the BBB?
# Also, are you seeing an “192.168.7.1” ip created on your Ubuntu PC?
# You can check this using:
# ifconfig -a
# You can check the ‘dmesg’ out on your PC to see if there are any errors connecting to the BBB.
# Jon
# **Pankaj_Rai**
# July 13, 2020,  5:54pm
# 9
# Hi,
# I’ve enabled the port 22 on my pc and I’m not using sd card for flashing so I don’t think i need to press the s2 button.
# And also i don’t have any debugger and i tried pinging the BBB on that address but it shows all the sent packets are lost so i think I’m unable to ping.
# Is there any other way to work this out?
# Thanks for your help
# Pankaj
# **Dennis_Bieber**
# July 13, 2020,  6:37pm
# 10
# That is only required if you have a VERY OLD image in the eMMC (like...
# Debian Wheezy! aka Debian v7). If the eMMC has been flashed with anything
# in the Jessie, Stretch, Buster time-frame it should have a u-boot which
# looks for the SD card, and transfers control to the SD card image to
# complete booting (it may have a different problem -- in that early images
# relied upon the kernel to load device trees, while newer images rely upon
# u-boot to load the device trees)..
# I have not used the BBB boot select button for something like three+
# years (and the BB AI doesn't even have a boot select button).
# **Dennis_Bieber**
# July 13, 2020,  6:48pm
# 11
# The surest is to NOT USE THE USB "network".
# I presume your main computer is connected to some router.
# Run an ethernet cable from the BBB to the same router. Connect a 5V
# power supply to the barrel connector on the BBB. (If you must, you might be
# able to use a 5V USB phone charger connected to the USB port -- but for
# this debugging you do NOT want the USB port connected to the main
# computer!)
# Check the router configuration pages for what IP # it assigned to the
# BBB (note: if the router is modern enough, it may do DNS and have assigned
# the host name beaglebone.local to the BBB, in which case you can connect
# using the host name instead of the router assigned IP #).
# **amf99**
# July 13, 2020,  7:31pm
# 12
# So this is the original image that came with the BBB?
# Like some one else just mentioned, you may want to use a ethernet cable connected to your router.
# Without knowing what image is on the BBB, it’s going to be difficult to trouble shoot this.
# **KenUnix**
# July 13, 2020,  8:26pm
# 13
# I thought you were running Windows.
# Can you ping 192.168.7.2 ?
# It might show up as a virtual tty or USB port. Running Linux host I have not done.
# If your using Windows pull up device manager and look in com/lpt ports and you
# should see a new one something like USB Serial port COM4. That’s what you
# should connect to.
# Sorry
# **Pankaj_Rai**
# July 14, 2020,  2:57am
# 14
# Hi,
# Can we connect the BBB using ethernet cable to the computers ethernet port?
# ( It’s because I’m living in hostel and here we have the hostel wifi available)
# And can we power the BBB using 5 V charger?
# If not, then will it work out on using the flashed sd card as boot? (I’m thinking to buy one(16gb) for this if doesn’t work)
# Thanks
# Pankaj
# **amf99**
# July 14, 2020,  2:55pm
# 15
# connecting the ethernet to the computer will not provide you with an IP address on the BBB. BBB wants to use dhcp to get an IP, which what happens when connected to the router.
# You should be able to ping 192.168.7.2 from the laptop, if you see 192.168.7.1 on the laptop.
# Is this your personal laptop or a company laptop? companies tend to secure laptops such that ping and ssh aren’t allowed (My personal experience)
# Would recommend getting an sdcard, again if this is a company laptop, it may not help.
# **Pankaj_Rai**
# July 14, 2020,  3:18pm
# 16
# Hi,
# Currently I’m working with my personal laptop only. And also i’ve ordered a 16 gb sd card for sure. But meanwhile i was trying to make it work with with preinstalled os in eMMC only.
# Is there any way we can update the eMMC OS? So that it may able to connect to 192.168.7.2 or 192.168.6.2 ( this is because somewhere i’ve seen that Linux system uses this ip to connect with BBB).
# Thanks
# Pankaj
# **Dennis_Bieber**
# July 14, 2020,  4:43pm
# 17
# Hi,
# Can we connect the BBB using ethernet cable to the computers ethernet port?
# You might need a cross-over cable -- though many newer NICs auto-detect
# if cross-over is needed and switch internally.
# ( It's because I'm living in hostel and here we have the hostel wifi
# available)
# Unfortunately, at this point you are back to configuring the host
# computer for Internet Connection Sharing -- otherwise there is no pass
# through from WiFi to the cable (heck, on my computer, in order to even use
# the WiFi I have to disable the cable connection -- it gives priority to the
# cable, even if there is no "internet" on that line! I have never tried to
# enable ICS).
# And can we power the BBB using 5 V charger?
# A Beaglebone Black power supply is 5V 2A, a BB AI should probably be a
# bit higher -- 5V 2.5-3A. The BBB has a barrel connector so common USB
# chargers may not be applicable -- I've not tried a 2A USB charger.
# **Dennis_Bieber**
# July 14, 2020,  5:02pm
# 18
# It uses those addresses only for the USB Gadget. If your computer shows
# an RNDIS device under network adapters (in device manager) you HAVE the
# 192.168.7.x connection. If (in a command prompt)
# ssh
# debian@192.168.7.2
# gives you a prompt for the beaglebone password
# **jomoengineer**
# July 14, 2020,  5:10pm
# 19
# I believe Pankaj is using Ubuntu and not Windows.
# Pankaj :
# I would suggest checking that your Ubuntu system is creating a 192.168.7.1 ipaddress and is not having an issue connecting to the board via ‘dmesg’.
# Jon
# **amf99**
# July 15, 2020,  2:49pm
# 20
# Only way to update the emmc os without a ethernet connection is by using a USB-to-SERIAL adapter, make sure to get the 3.3 volt version.
# Not sure if you answered the prior question. does your laptop show 192.168.6.1 and/or 192.168.7.1 when doing ‘ifconfig -a’ from a terminal window?
# If it does, I don’t see any reason why you cannot at least ping the BBB at 6.2 or 7.2.
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled

# %%
import re

def structure_posts(lines, usernames):
    discussion = []
    post = None

    # Regex for date line like "September 6, 2023, 4:55pm"
    date_re = re.compile(r'^[A-Z][a-z]+ \d{1,2}, \d{4},\s+\d{1,2}:\d{2}(am|pm)$')

    for line in lines:
        # Detect new user line (highlighted: **username**)
        user_match = re.match(r'^\*\*([a-zA-Z0-9_-]+)\*\*$', line)
        if user_match:
            if post:
                discussion.append(post)
            post = {
                'user': user_match.group(1),
                'msg': ''
            }
        elif post:
            if date_re.match(line):
                post['time'] = line
            elif re.match(r'^\d+$', line):
                post['num'] = line
            else:
                post['msg'] += line + '\n'
        # If line before any user, skip it

    if post:
        discussion.append(post)

    return discussion

# Run on highlighted output from previous cell
discussion = structure_posts(highlighted_lines, usernames)

# Print it out cleanly
for p in discussion:
    user = p.get('user', '?')
    time = p.get('time', '')
    num = p.get('num', '')
    msg = p.get('msg', '').strip()
    print(f"**{user}** | **{time}** | **Post #{num}**")
    print(msg)
    print('-' * 60)
# Out:
# **Pankaj_Rai** | **June 26, 2020, 11:59am** | **Post #1**
# HI,
# I’m just getting started with the BBB and i’m trying to go to on board server 192.168.7.2 as mentioned in the Getting started doc.
# But the problem is that 192.168.7.2 is not opening or not reachable. While I have interfaced the BBB with mini B cable to laptop(I’m using Ubuntu 18.0.04 in it) and also connected the BBB with ethernet cable to my laptop.
# Please suggest the possible cause and how to debug and make it work.
# thanks
# Pankaj
# ------------------------------------------------------------
# **amf99** | **June 26, 2020,  4:00pm** | **Post #2**
# What Image are you using?
# cat /etc/dogtag (provided it is a debian image)
# or sudo /opt/scripts/tools/version.sh
# or uname -a (might help)
# How are you powering the board, 5v supply or usb? if usb, is it via a powered hub?
# can you also provide the output of ifconfig from the beaglebone black?
# Does Nautilus show BEAGLEBONE folder?
# I’m running ‘
# BeagleBoard.org
# Debian Image 2019-08-03’ and am able to ssh to the beaglebone black on 7.2 and 6.1 from desktop (ubuntu 18.04)
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 12, 2020,  5:44pm** | **Post #3**
# Hi amf,
# it’s been a while since I’ve started using BBB. So, I dont know actually how to get started with BBB.
# I haven’t installed any image on BBB on my own. I just followed the steps mentioned in Readme of BBB. (I’ve attached the SS for your reference). Do we need to install any image to BBB first?
# Don’t the BBB comes with the preinstalled OS (or image)?
# kindly guide me through this.
# thanks
# Pankaj
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 12, 2020,  6:39pm** | **Post #4**
# ssh: connect to host 192.168.7.1 port 22: Connection timed out
# this is what i’m getting as error while connecting BBB to 192.68.7.2
# what could be the reason and how can we resolve this issue.
# thanks
# Pankaj
# ------------------------------------------------------------
# **KenUnix** | **July 13, 2020,  5:10pm** | **Post #5**
# If you have not modified it’s configuration you should ssh to 196.168.7.2
# 192.168.7.1 is the P.C. side.of the connection.
# When powering the BBB up and connecting the USB cable does the PC play the UP tone?
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 13, 2020,  5:13pm** | **Post #6**
# Hi,
# Pc does play a sound while connecting BBB to pc. And I’ve not changed any configuration of the BBB.
# Thanks.
# ------------------------------------------------------------
# **amf99** | **July 13, 2020,  5:43pm** | **Post #7**
# Your using Ubuntu 18.0.04 good, this is what I’m using also. Are you using any firewall software, like ufw, if you are, make sure port 22 is allowed.
# Yes, BBB comes with pre-install OS. If your BBB boots without and sdcard, then it is booting form the emmc.
# to boot from the sdcard, you have to hold the ‘USER’ button during the boot process. (that is from the time the power is applied, till the leds start flickering)
# Do you have a USB-TO-SERIAL converter that can be connected to J1, it may help in debugging the issue.
# Can you ping 192.168.7.2 from your lap top?
# When you ssh, are you using debian or root?
# You do have openssh
# -
# server installed on the laptop, right?
# ------------------------------------------------------------
# **jomoengineer** | **July 13, 2020,  5:44pm** | **Post #8**
# What image are you running on the BBB?
# Also, are you seeing an “192.168.7.1” ip created on your Ubuntu PC?
# You can check this using:
# ifconfig -a
# You can check the ‘dmesg’ out on your PC to see if there are any errors connecting to the BBB.
# Jon
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 13, 2020,  5:54pm** | **Post #9**
# Hi,
# I’ve enabled the port 22 on my pc and I’m not using sd card for flashing so I don’t think i need to press the s2 button.
# And also i don’t have any debugger and i tried pinging the BBB on that address but it shows all the sent packets are lost so i think I’m unable to ping.
# Is there any other way to work this out?
# Thanks for your help
# Pankaj
# ------------------------------------------------------------
# **Dennis_Bieber** | **July 13, 2020,  6:37pm** | **Post #10**
# That is only required if you have a VERY OLD image in the eMMC (like...
# Debian Wheezy! aka Debian v7). If the eMMC has been flashed with anything
# in the Jessie, Stretch, Buster time-frame it should have a u-boot which
# looks for the SD card, and transfers control to the SD card image to
# complete booting (it may have a different problem -- in that early images
# relied upon the kernel to load device trees, while newer images rely upon
# u-boot to load the device trees)..
# I have not used the BBB boot select button for something like three+
# years (and the BB AI doesn't even have a boot select button).
# ------------------------------------------------------------
# **Dennis_Bieber** | **July 13, 2020,  6:48pm** | **Post #11**
# The surest is to NOT USE THE USB "network".
# I presume your main computer is connected to some router.
# Run an ethernet cable from the BBB to the same router. Connect a 5V
# power supply to the barrel connector on the BBB. (If you must, you might be
# able to use a 5V USB phone charger connected to the USB port -- but for
# this debugging you do NOT want the USB port connected to the main
# computer!)
# Check the router configuration pages for what IP # it assigned to the
# BBB (note: if the router is modern enough, it may do DNS and have assigned
# the host name beaglebone.local to the BBB, in which case you can connect
# using the host name instead of the router assigned IP #).
# ------------------------------------------------------------
# **amf99** | **July 13, 2020,  7:31pm** | **Post #12**
# So this is the original image that came with the BBB?
# Like some one else just mentioned, you may want to use a ethernet cable connected to your router.
# Without knowing what image is on the BBB, it’s going to be difficult to trouble shoot this.
# ------------------------------------------------------------
# **KenUnix** | **July 13, 2020,  8:26pm** | **Post #13**
# I thought you were running Windows.
# Can you ping 192.168.7.2 ?
# It might show up as a virtual tty or USB port. Running Linux host I have not done.
# If your using Windows pull up device manager and look in com/lpt ports and you
# should see a new one something like USB Serial port COM4. That’s what you
# should connect to.
# Sorry
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 14, 2020,  2:57am** | **Post #14**
# Hi,
# Can we connect the BBB using ethernet cable to the computers ethernet port?
# ( It’s because I’m living in hostel and here we have the hostel wifi available)
# And can we power the BBB using 5 V charger?
# If not, then will it work out on using the flashed sd card as boot? (I’m thinking to buy one(16gb) for this if doesn’t work)
# Thanks
# Pankaj
# ------------------------------------------------------------
# **amf99** | **July 14, 2020,  2:55pm** | **Post #15**
# connecting the ethernet to the computer will not provide you with an IP address on the BBB. BBB wants to use dhcp to get an IP, which what happens when connected to the router.
# You should be able to ping 192.168.7.2 from the laptop, if you see 192.168.7.1 on the laptop.
# Is this your personal laptop or a company laptop? companies tend to secure laptops such that ping and ssh aren’t allowed (My personal experience)
# Would recommend getting an sdcard, again if this is a company laptop, it may not help.
# ------------------------------------------------------------
# **Pankaj_Rai** | **July 14, 2020,  3:18pm** | **Post #16**
# Hi,
# Currently I’m working with my personal laptop only. And also i’ve ordered a 16 gb sd card for sure. But meanwhile i was trying to make it work with with preinstalled os in eMMC only.
# Is there any way we can update the eMMC OS? So that it may able to connect to 192.168.7.2 or 192.168.6.2 ( this is because somewhere i’ve seen that Linux system uses this ip to connect with BBB).
# Thanks
# Pankaj
# ------------------------------------------------------------
# **Dennis_Bieber** | **July 14, 2020,  4:43pm** | **Post #17**
# Hi,
# Can we connect the BBB using ethernet cable to the computers ethernet port?
# You might need a cross-over cable -- though many newer NICs auto-detect
# if cross-over is needed and switch internally.
# ( It's because I'm living in hostel and here we have the hostel wifi
# available)
# Unfortunately, at this point you are back to configuring the host
# computer for Internet Connection Sharing -- otherwise there is no pass
# through from WiFi to the cable (heck, on my computer, in order to even use
# the WiFi I have to disable the cable connection -- it gives priority to the
# cable, even if there is no "internet" on that line! I have never tried to
# enable ICS).
# And can we power the BBB using 5 V charger?
# A Beaglebone Black power supply is 5V 2A, a BB AI should probably be a
# bit higher -- 5V 2.5-3A. The BBB has a barrel connector so common USB
# chargers may not be applicable -- I've not tried a 2A USB charger.
# ------------------------------------------------------------
# **Dennis_Bieber** | **July 14, 2020,  5:02pm** | **Post #18**
# It uses those addresses only for the USB Gadget. If your computer shows
# an RNDIS device under network adapters (in device manager) you HAVE the
# 192.168.7.x connection. If (in a command prompt)
# ssh
# debian@192.168.7.2
# gives you a prompt for the beaglebone password
# ------------------------------------------------------------
# **jomoengineer** | **July 14, 2020,  5:10pm** | **Post #19**
# I believe Pankaj is using Ubuntu and not Windows.
# Pankaj :
# I would suggest checking that your Ubuntu system is creating a 192.168.7.1 ipaddress and is not having an issue connecting to the board via ‘dmesg’.
# Jon
# ------------------------------------------------------------
# **amf99** | **July 15, 2020,  2:49pm** | **Post #20**
# Only way to update the emmc os without a ethernet connection is by using a USB-to-SERIAL adapter, make sure to get the 3.3 volt version.
# Not sure if you answered the prior question. does your laptop show 192.168.6.1 and/or 192.168.7.1 when doing ‘ifconfig -a’ from a terminal window?
# If it does, I don’t see any reason why you cannot at least ping the BBB at 6.2 or 7.2.
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
# ------------------------------------------------------------

# %%
import json
import re
import requests
from bs4 import BeautifulSoup
import time

def normalize_thread_url(url):
    url = url.split('#')[0]
    parts = url.rstrip('/').split('/')
    if parts[-1].isdigit() and int(parts[-1]) < 500:
        url = '/'.join(parts[:-1])
    return url

def get_thread_title(soup):
    title_tag = soup.find('title')
    if title_tag:
        return title_tag.text.split('-')[0].strip()
    return ""

def extract_posts(soup):
    posts = []
    for post_div in soup.find_all('div', class_='topic-body'):
        num = None
        pos_span = post_div.find('span', {'itemprop': 'position'})
        if pos_span and pos_span.text.strip().isdigit():
            num = int(pos_span.text.strip())
        user = None
        creator = post_div.find('span', class_='creator')
        if creator:
            user_span = creator.find('span', {'itemprop': 'name'})
            if user_span:
                user = user_span.text.strip()
        content_div = post_div.find('div', class_='post')
        content = content_div.get_text(separator='\n', strip=True) if content_div else ''
        posts.append({'num': num, 'user': user, 'content': content})
    return posts

def scrape_thread(thread_url, session=None, delay=0.5):
    if session is None:
        session = requests.Session()
        session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
        })
    base_url = normalize_thread_url(thread_url)
    all_posts = []
    seen_nums = set()
    last_num = 0
    try:
        resp = session.get(base_url, timeout=10)
        resp.raise_for_status()
    except Exception as e:
        print(f"Failed to fetch {base_url}: {e}")
        return None
    soup = BeautifulSoup(resp.text, 'html.parser')
    thread_name = get_thread_title(soup)
    posts = extract_posts(soup)
    for post in posts:
        if post['num'] and post['num'] not in seen_nums:
            all_posts.append(post)
            seen_nums.add(post['num'])
            last_num = max(last_num, post['num'] or 0)
    time.sleep(delay)
    next_num = last_num + 1
    while True:
        next_url = f"{base_url}/{next_num}"
        try:
            resp = session.get(next_url, timeout=10)
            if resp.status_code != 200:
                break
        except Exception as e:
            print(f"Failed to fetch {next_url}: {e}")
            break
        soup = BeautifulSoup(resp.text, 'html.parser')
        posts = extract_posts(soup)
        found = False
        for post in posts:
            if post['num'] and post['num'] not in seen_nums:
                all_posts.append(post)
                seen_nums.add(post['num'])
                last_num = max(last_num, post['num'] or 0)
                found = True
        if not found:
            break
        next_num = last_num + 1
        time.sleep(delay)
    content = '\n\n'.join(
        f"Post #{p['num']} by {p['user']}:\n{p['content']}" for p in sorted(all_posts, key=lambda x: x['num'] or 0)
    )
    return {
        'url': base_url,
        'thread_name': thread_name,
        'content': content,
        'num_replies': len(all_posts)
    }

# Read links from filtered_threads.txt and scrape all threads
with open('filtered_threads.txt', 'r') as f:
    links = [line.strip() for line in f if line.strip()]
thread_urls = set(normalize_thread_url(url) for url in links)
results = []
for url in thread_urls:
    print(f"Scraping: {url}")
    data = scrape_thread(url)
    if data:
        results.append(data)
        print(f"Done: {data['thread_name']} ({data['num_replies']} replies)")
    else:
        print(f"Failed: {url}")
with open('scraped_threads_complete.json', 'w', encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
print("All threads scraped and saved to scraped_threads_complete.json")
# Out:
# Scraping: https://forum.beagleboard.org/t/librobotcontrol-support-for-newer-boards/37187
# Done: librobotcontrol support for newer boards (19 replies)
# Scraping: https://forum.beagleboard.org/t/video-of-the-open-source-chip-design-panel/29256
# Done: librobotcontrol support for newer boards (19 replies)
# Scraping: https://forum.beagleboard.org/t/video-of-the-open-source-chip-design-panel/29256
# Done: Video of the Open Source Chip Design panel (2 replies)
# Scraping: https://forum.beagleboard.org/t/repo-access-and-re-build-scripts/42187
# Done: Video of the Open Source Chip Design panel (2 replies)
# Scraping: https://forum.beagleboard.org/t/repo-access-and-re-build-scripts/42187
# Done: Repo access and re (2 replies)
# Scraping: https://forum.beagleboard.org/t/recover-beagleplay/41533
# Done: Repo access and re (2 replies)
# Scraping: https://forum.beagleboard.org/t/recover-beagleplay/41533
# Done: recover beagleplay (3 replies)
# Scraping: https://forum.beagleboard.org/t/impossible-to-attach-plain-text/30431
# Done: recover beagleplay (3 replies)
# Scraping: https://forum.beagleboard.org/t/impossible-to-attach-plain-text/30431
# Done: Impossible to attach plain text (7 replies)
# Scraping: https://forum.beagleboard.org/t/open-hardware-summit-panel-on-chip-design-today/29169
# Done: Impossible to attach plain text (7 replies)
# Scraping: https://forum.beagleboard.org/t/open-hardware-summit-panel-on-chip-design-today/29169
# Done: Open Hardware Summit panel on chip design today (1 replies)
# Scraping: https://forum.beagleboard.org/t/how-long-does-the-lts-from-the-beagleboard-org-foundation-last/31614
# Done: Open Hardware Summit panel on chip design today (1 replies)
# Scraping: https://forum.beagleboard.org/t/how-long-does-the-lts-from-the-beagleboard-org-foundation-last/31614
# Done: how long does the LTS from the beagleboard.org foundation last (3 replies)
# Scraping: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Done: how long does the LTS from the beagleboard.org foundation last (3 replies)
# Scraping: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Failed to fetch https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/i2c-bus-speed-beaglev-fire/41101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b973e150>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Scraping: https://forum.beagleboard.org/t/debian-image-differences-for-ai64/32601
# Failed to fetch https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/i2c-bus-speed-beaglev-fire/41101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b973e150>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Scraping: https://forum.beagleboard.org/t/debian-image-differences-for-ai64/32601
# Done: Debian image differences for AI64 (3 replies)
# Scraping: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Done: Debian image differences for AI64 (3 replies)
# Scraping: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Failed to fetch https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8846f30>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Scraping: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Failed to fetch https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8846f30>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Scraping: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Failed to fetch https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8846870>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Failed to fetch https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8846870>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886bd40>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Scraping: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886bd40>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Scraping: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Failed to fetch https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleplay-wired-ethernet-doesnt-receive-packets/38994 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886b470>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Scraping: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Failed to fetch https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleplay-wired-ethernet-doesnt-receive-packets/38994 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886b470>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Scraping: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Failed to fetch https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/ai-64-remoteproc-confusion/32238 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8847800>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Scraping: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Failed to fetch https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/ai-64-remoteproc-confusion/32238 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8847800>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Scraping: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Failed to fetch https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/need-to-enable-7-uart-on-beaglebone-ai-64/33936 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88458e0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-wont-power-with-usb-cable/36670
# Failed to fetch https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/need-to-enable-7-uart-on-beaglebone-ai-64/33936 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88458e0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-wont-power-with-usb-cable/36670
# Done: BeagleBone Blue Won't Power with USB Cable (2 replies)
# Scraping: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Done: BeagleBone Blue Won't Power with USB Cable (2 replies)
# Scraping: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Failed to fetch https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglecast-episode-on-beagley-ai/38030 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b9a28500>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Scraping: https://forum.beagleboard.org/t/question-is-ai-64-currently-shipping-with-production-processor-and-no-pru/32370
# Failed to fetch https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglecast-episode-on-beagley-ai/38030 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b9a28500>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Scraping: https://forum.beagleboard.org/t/question-is-ai-64-currently-shipping-with-production-processor-and-no-pru/32370
# Done: Question (15 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Done: Question (15 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b96a8ec0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Scraping: https://forum.beagleboard.org/t/unable-to-use-github-2fa-with-openbeagle-org/37092
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b96a8ec0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Scraping: https://forum.beagleboard.org/t/unable-to-use-github-2fa-with-openbeagle-org/37092
# Done: unable to use github 2fa with openbeagle.org (8 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-ai-no-usb-virtual-serial-port-and-ram-size-is-less-than-1g/32067
# Done: unable to use github 2fa with openbeagle.org (8 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-ai-no-usb-virtual-serial-port-and-ram-size-is-less-than-1g/32067
# Done: Beaglebone AI (2 replies)
# Scraping: https://forum.beagleboard.org/t/dates-for-gsoc-2025-announced/40900
# Done: Beaglebone AI (2 replies)
# Scraping: https://forum.beagleboard.org/t/dates-for-gsoc-2025-announced/40900
# Done: Dates for GSoC 2025 announced (1 replies)
# Scraping: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Done: Dates for GSoC 2025 announced (1 replies)
# Scraping: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Failed to fetch https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/pocketbeagle-2-with-am6254/42035 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84fd340>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Scraping: https://forum.beagleboard.org/t/tda4vm-debian-11-3-flasher-does-not-produce-a-functional-emmc/33288
# Failed to fetch https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/pocketbeagle-2-with-am6254/42035 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84fd340>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Scraping: https://forum.beagleboard.org/t/tda4vm-debian-11-3-flasher-does-not-produce-a-functional-emmc/33288
# Done: TDA4VM Debian 11.3 Flasher does not produce a functional eMMC (10 replies)
# Scraping: https://forum.beagleboard.org/t/unable-to-login-using-github/41012
# Done: TDA4VM Debian 11.3 Flasher does not produce a functional eMMC (10 replies)
# Scraping: https://forum.beagleboard.org/t/unable-to-login-using-github/41012
# Done: unable to login using GitHub (2 replies)
# Scraping: https://forum.beagleboard.org/t/booting-the-new-beaglebone-black-board/41652
# Done: unable to login using GitHub (2 replies)
# Scraping: https://forum.beagleboard.org/t/booting-the-new-beaglebone-black-board/41652
# Done: Booting the New Beaglebone Black Board (16 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Done: Booting the New Beaglebone Black Board (16 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Failed to fetch https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleplay-sd-card-boot-fail/35820 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886abd0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Scraping: https://forum.beagleboard.org/t/gpio-on-am57xx/41232
# Failed to fetch https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleplay-sd-card-boot-fail/35820 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b886abd0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Scraping: https://forum.beagleboard.org/t/gpio-on-am57xx/41232
# Done: GPIO on am57xx (2 replies)
# Scraping: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Done: GPIO on am57xx (2 replies)
# Scraping: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Failed to fetch https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black: 404 Client Error: Not Found for url: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Failed: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-differentiable-logic-for-interactive-systems-and-generative-music/38486
# Failed to fetch https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black: 404 Client Error: Not Found for url: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Failed: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-differentiable-logic-for-interactive-systems-and-generative-music/38486
# Done: Weekly Progress Report: Differentiable Logic for Interactive Systems and Generative Music (14 replies)
# Scraping: https://forum.beagleboard.org/t/if-cape-eeprom-part-number-field-contains-a-space-number-the-number-is-interpreted-as-init-runlevel-lol/37682
# Done: Weekly Progress Report: Differentiable Logic for Interactive Systems and Generative Music (14 replies)
# Scraping: https://forum.beagleboard.org/t/if-cape-eeprom-part-number-field-contains-a-space-number-the-number-is-interpreted-as-init-runlevel-lol/37682
# Done: If cape EEPROM part number field contains a space+number the number is interpreted as /init runlevel (lol) (1 replies)
# Scraping: https://forum.beagleboard.org/t/gitlab-approval/41016
# Done: If cape EEPROM part number field contains a space+number the number is interpreted as /init runlevel (lol) (1 replies)
# Scraping: https://forum.beagleboard.org/t/gitlab-approval/41016
# Done: Gitlab approval (1 replies)
# Scraping: https://forum.beagleboard.org/t/building-with-buildroot-and-assisting-others/31953
# Done: Gitlab approval (1 replies)
# Scraping: https://forum.beagleboard.org/t/building-with-buildroot-and-assisting-others/31953
# Done: Building with Buildroot and Assisting Others (3 replies)
# Scraping: https://forum.beagleboard.org/t/accessing-beagleplay-gpios-and-csi/34390
# Done: Building with Buildroot and Assisting Others (3 replies)
# Scraping: https://forum.beagleboard.org/t/accessing-beagleplay-gpios-and-csi/34390
# Done: Accessing BeaglePlay GPIOs and CSI (12 replies)
# Scraping: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Done: Accessing BeaglePlay GPIOs and CSI (12 replies)
# Scraping: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Failed to fetch https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b83ebce0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Scraping: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Failed to fetch https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b83ebce0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Scraping: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Failed to fetch https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/kernel-module-cross-compilation/35579 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8405d90>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Failed to fetch https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/kernel-module-cross-compilation/35579 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8405d90>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Failed to fetch https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84066f0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Scraping: https://forum.beagleboard.org/t/beaglev-fire-cape-4-uarts-only-has-3-uarts-showing-up-in-linux/41574
# Failed to fetch https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84066f0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Scraping: https://forum.beagleboard.org/t/beaglev-fire-cape-4-uarts-only-has-3-uarts-showing-up-in-linux/41574
# Done: BeagleV (3 replies)
# Scraping: https://forum.beagleboard.org/t/did-anyone-purchase-the-book-mastering-embedded-linux-development-vasquez-simmonds-2025/42197
# Done: BeagleV (3 replies)
# Scraping: https://forum.beagleboard.org/t/did-anyone-purchase-the-book-mastering-embedded-linux-development-vasquez-simmonds-2025/42197
# Done: Did Anyone Purchase the Book / "Mastering Embedded Linux Development (Vasquez, Simmonds 2025)." (6 replies)
# Scraping: https://forum.beagleboard.org/t/bbgv1-usb-gadget-ethernet-windows-10-linux-mint/31771
# Done: Did Anyone Purchase the Book / "Mastering Embedded Linux Development (Vasquez, Simmonds 2025)." (6 replies)
# Scraping: https://forum.beagleboard.org/t/bbgv1-usb-gadget-ethernet-windows-10-linux-mint/31771
# Done: BBGv1 USB "Gadget" Ethernet?  Windows 10 & Linux Mint (2 replies)
# Scraping: https://forum.beagleboard.org/t/micro-sdxc-card-in-bb-ai-64-gives-black-screen-and-only-solid-light/34740
# Done: BBGv1 USB "Gadget" Ethernet?  Windows 10 & Linux Mint (2 replies)
# Scraping: https://forum.beagleboard.org/t/micro-sdxc-card-in-bb-ai-64-gives-black-screen-and-only-solid-light/34740
# Done: MIcro SDXC card in BB AI (3 replies)
# Scraping: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Done: MIcro SDXC card in BB AI (3 replies)
# Scraping: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Failed to fetch https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/tivxalgivisioncreate-returned-null/38407 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b82e6030>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Scraping: https://forum.beagleboard.org/t/wth-automation-engineer-or-technician-or-consutant/31630
# Failed to fetch https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/tivxalgivisioncreate-returned-null/38407 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b82e6030>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Scraping: https://forum.beagleboard.org/t/wth-automation-engineer-or-technician-or-consutant/31630
# Done: WTH: Automation Engineer or Technician or Consutant (1 replies)
# Scraping: https://forum.beagleboard.org/t/trying-to-perform-inference-on-my-compiled-model-in-beagle-bone-ai64-using-this-repo-https-github-com-wasabifan-tidl-yolov5-custom-model-demo/38468
# Done: WTH: Automation Engineer or Technician or Consutant (1 replies)
# Scraping: https://forum.beagleboard.org/t/trying-to-perform-inference-on-my-compiled-model-in-beagle-bone-ai64-using-this-repo-https-github-com-wasabifan-tidl-yolov5-custom-model-demo/38468
# Done: Trying to perform inference on my compiled model in beagle bone ai64, using this repo : (4 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-not-fully-powering-off-on-shutdown-w-debian-12-9-xfce-flasher-image/41398
# Done: Trying to perform inference on my compiled model in beagle bone ai64, using this repo : (4 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-not-fully-powering-off-on-shutdown-w-debian-12-9-xfce-flasher-image/41398
# Done: BeaglePlay not fully powering off on shutdown w/ Debian 12.9 XFCE flasher image (4 replies)
# Scraping: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Done: BeaglePlay not fully powering off on shutdown w/ Debian 12.9 XFCE flasher image (4 replies)
# Scraping: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Failed to fetch https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/error-message-when-cloning-pru-cookbook/33664 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b831f560>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Scraping: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Failed to fetch https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/error-message-when-cloning-pru-cookbook/33664 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b831f560>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Scraping: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Failed to fetch https://forum.beagleboard.org/t/kernel-panic-on-boot/38690: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/kernel-panic-on-boot/38690 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a5820>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Scraping: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Failed to fetch https://forum.beagleboard.org/t/kernel-panic-on-boot/38690: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/kernel-panic-on-boot/38690 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a5820>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Scraping: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Failed to fetch https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/debian-10-x-buster-monthly-snapshots/31203 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a61e0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Scraping: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Failed to fetch https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/debian-10-x-buster-monthly-snapshots/31203 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a61e0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Scraping: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Failed to fetch https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84637d0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Scraping: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Failed to fetch https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b84637d0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Scraping: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Failed to fetch https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8461a60>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Scraping: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Failed to fetch https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8461a60>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Scraping: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Failed to fetch https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/zephyr-related-projects-for-2025/40001 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8462420>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Scraping: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Failed to fetch https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/zephyr-related-projects-for-2025/40001 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8462420>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Scraping: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Failed to fetch https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a5ee0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Scraping: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Failed to fetch https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b88a5ee0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Scraping: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Failed to fetch https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b975a690>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Scraping: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Failed to fetch https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b975a690>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Scraping: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Failed to fetch https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b880a9f0>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Scraping: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Failed to fetch https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b880a9f0>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Scraping: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Failed to fetch https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8461700>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Scraping: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Failed to fetch https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8461700>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Scraping: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Failed to fetch https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8462510>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Scraping: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Failed to fetch https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8462510>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Scraping: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-ai-64-adc-voltage-question/42211 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8462f60>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Scraping: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-ai-64-adc-voltage-question/42211 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8462f60>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Scraping: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Failed to fetch https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8a1ef30>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Scraping: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Failed to fetch https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b8a1ef30>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Scraping: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Failed to fetch https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/how-long-until-my-posts-do-no-have-to-be-approved/30525 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b83ea480>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Scraping: https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015
# Failed to fetch https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/how-long-until-my-posts-do-no-have-to-be-approved/30525 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b83ea480>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Scraping: https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015
# Failed to fetch https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b88a5b20>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015
# Scraping: https://forum.beagleboard.org/t/deep-sleep-wake-through-gpio-and-rtc/26007
# ...
# Done: Repeated Binding of Display Controller (dc8200) in Kernel Logs – BeagleV Display Subsystem Issue? (2 replies)
# Scraping: https://forum.beagleboard.org/t/enhanced-media-experience-with-ai-powered-commercial-detection-and-replacement/37358
# Done: Enhanced Media Experience with AI (35 replies)
# Scraping: https://forum.beagleboard.org/t/u-boot-console-on-bblue/33465
# Done: Enhanced Media Experience with AI (35 replies)
# Scraping: https://forum.beagleboard.org/t/u-boot-console-on-bblue/33465
# Done: U (2 replies)
# Scraping: https://forum.beagleboard.org/t/accessing-p9-pins-via-devmem2/37648
# Done: U (2 replies)
# Scraping: https://forum.beagleboard.org/t/accessing-p9-pins-via-devmem2/37648
# Done: Accessing P9 (5 replies)
# Scraping: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Done: Accessing P9 (5 replies)
# Scraping: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Failed to fetch https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglev-fire-os-updating/41914 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b81c9e80>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Scraping: https://forum.beagleboard.org/t/emmc-drive-disappears-on-bbai-64/33193
# Failed to fetch https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglev-fire-os-updating/41914 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b81c9e80>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Scraping: https://forum.beagleboard.org/t/emmc-drive-disappears-on-bbai-64/33193
# Done: eMMC drive disappears on BBAI (5 replies)
# Scraping: https://forum.beagleboard.org/t/am5729-debian-10-3-2020-04-06-device-tree/35748
# Done: eMMC drive disappears on BBAI (5 replies)
# Scraping: https://forum.beagleboard.org/t/am5729-debian-10-3-2020-04-06-device-tree/35748
# Done: AM5729 Debian 10.3 2020 (6 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-dimensions/38780
# Done: AM5729 Debian 10.3 2020 (6 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-dimensions/38780
# Done: Beaglebone Blue dimensions (4 replies)
# Scraping: https://forum.beagleboard.org/t/beaglemind-prompts/42210
# Done: Beaglebone Blue dimensions (4 replies)
# Scraping: https://forum.beagleboard.org/t/beaglemind-prompts/42210
# Done: BeagleMind Prompts (2 replies)
# Scraping: https://forum.beagleboard.org/t/fix-beaglev-ahead-support/41744
# Done: BeagleMind Prompts (2 replies)
# Scraping: https://forum.beagleboard.org/t/fix-beaglev-ahead-support/41744
# Done: Fix beaglev ahead support (5 replies)
# Scraping: https://forum.beagleboard.org/t/sd-card-booting-issue/41911
# Done: Fix beaglev ahead support (5 replies)
# Scraping: https://forum.beagleboard.org/t/sd-card-booting-issue/41911
# Done: SD CARD BOOTING ISSUE (2 replies)
# Scraping: https://forum.beagleboard.org/t/full-time-openings-at-proaxion/34709
# Done: SD CARD BOOTING ISSUE (2 replies)
# Scraping: https://forum.beagleboard.org/t/full-time-openings-at-proaxion/34709
# Done: Full (1 replies)
# Scraping: https://forum.beagleboard.org/t/android-12l-for-beagleboard-x15/32757
# Done: Full (1 replies)
# Scraping: https://forum.beagleboard.org/t/android-12l-for-beagleboard-x15/32757
# Done: Android 12L for BeagleBoard x15 (3 replies)
# Scraping: https://forum.beagleboard.org/t/booting-issue/39599
# Done: Android 12L for BeagleBoard x15 (3 replies)
# Scraping: https://forum.beagleboard.org/t/booting-issue/39599
# Done: Booting Issue (4 replies)
# Scraping: https://forum.beagleboard.org/t/passing-mailbox-messages-between-arm-and-pru/33772
# Done: Booting Issue (4 replies)
# Scraping: https://forum.beagleboard.org/t/passing-mailbox-messages-between-arm-and-pru/33772
# Done: Passing Mailbox messages between ARM and PRU (53 replies)
# Scraping: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Done: Passing Mailbox messages between ARM and PRU (53 replies)
# Scraping: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Failed to fetch https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b880a840>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Scraping: https://forum.beagleboard.org/t/ble-support-with-firmware-that-comes-with-beagleplay/41948
# Failed to fetch https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b880a840>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Failed: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Scraping: https://forum.beagleboard.org/t/ble-support-with-firmware-that-comes-with-beagleplay/41948
# Done: BLE support with firmware that comes with BeaglePlay (2 replies)
# Scraping: https://forum.beagleboard.org/t/pin-map-spreadsheet-for-x15/28836
# Done: BLE support with firmware that comes with BeaglePlay (2 replies)
# Scraping: https://forum.beagleboard.org/t/pin-map-spreadsheet-for-x15/28836
# Done: Pin map spreadsheet for X15 (4 replies)
# Scraping: https://forum.beagleboard.org/t/debian-11-x-bullseye-monthly-snapshots/31280
# Done: Pin map spreadsheet for X15 (4 replies)
# Scraping: https://forum.beagleboard.org/t/debian-11-x-bullseye-monthly-snapshots/31280
# Done: Debian 11.x (Bullseye) (4 replies)
# Scraping: https://forum.beagleboard.org/t/getting-started-with-the-beagley-ai/38662
# Done: Debian 11.x (Bullseye) (4 replies)
# Scraping: https://forum.beagleboard.org/t/getting-started-with-the-beagley-ai/38662
# Done: Getting Started with the BeagleY (1 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-cannot-detect-i2c-devices/676
# Done: Getting Started with the BeagleY (1 replies)
# Scraping: https://forum.beagleboard.org/t/beaglebone-blue-cannot-detect-i2c-devices/676
# Done: BeagleBone Blue cannot detect i2c devices (25 replies)
# Scraping: https://forum.beagleboard.org/t/bb-ai64-gpio-basics/36032
# Done: BeagleBone Blue cannot detect i2c devices (25 replies)
# Scraping: https://forum.beagleboard.org/t/bb-ai64-gpio-basics/36032
# Done: BB (16 replies)
# Scraping: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Done: BB (16 replies)
# Scraping: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Failed to fetch https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b86f6b70>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Scraping: https://forum.beagleboard.org/t/micro-sdxc-card-in-bb-ai-64-gives-black-screen-and-only-flashing-light/33904
# Failed to fetch https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b86f6b70>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Failed: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Scraping: https://forum.beagleboard.org/t/micro-sdxc-card-in-bb-ai-64-gives-black-screen-and-only-flashing-light/33904
# Done: Micro SDXC card in BB AI (13 replies)
# Scraping: https://forum.beagleboard.org/t/bbai64-how-many-uart-active/33559
# Done: Micro SDXC card in BB AI (13 replies)
# Scraping: https://forum.beagleboard.org/t/bbai64-how-many-uart-active/33559
# Done: BBAI64 _ How many UART active? (28 replies)
# Scraping: https://forum.beagleboard.org/t/unable-to-start-with-bb-ai-64/38626
# Done: BBAI64 _ How many UART active? (28 replies)
# Scraping: https://forum.beagleboard.org/t/unable-to-start-with-bb-ai-64/38626
# Done: unable to start with BB ai (5 replies)
# Scraping: https://forum.beagleboard.org/t/kvm-virtualization-support-bbx15/31316
# Done: unable to start with BB ai (5 replies)
# Scraping: https://forum.beagleboard.org/t/kvm-virtualization-support-bbx15/31316
# Done: KVM/Virtualization Support BBX15 (2 replies)
# Scraping: https://forum.beagleboard.org/t/beglebone-ai64-and-processor-sdk-linux-edge-ai-for-tda4vm-09-02-00/38609
# Done: KVM/Virtualization Support BBX15 (2 replies)
# Scraping: https://forum.beagleboard.org/t/beglebone-ai64-and-processor-sdk-linux-edge-ai-for-tda4vm-09-02-00/38609
# Done: Beglebone AI64 and Processor SDK Linux Edge AI for TDA4VM 09_02_00 (4 replies)
# Scraping: https://forum.beagleboard.org/t/where-are-the-files/42186
# Done: Beglebone AI64 and Processor SDK Linux Edge AI for TDA4VM 09_02_00 (4 replies)
# Scraping: https://forum.beagleboard.org/t/where-are-the-files/42186
# Done: Where are the files? (2 replies)
# Scraping: https://forum.beagleboard.org/t/cannot-write-to-on-board-cc1352p7-of-beagleplay/40305
# Done: Where are the files? (2 replies)
# Scraping: https://forum.beagleboard.org/t/cannot-write-to-on-board-cc1352p7-of-beagleplay/40305
# Done: Cannot write to on board CC1352P7 of BeaglePlay (10 replies)
# Scraping: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484?page=2
# Done: Cannot write to on board CC1352P7 of BeaglePlay (10 replies)
# Scraping: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484?page=2
# Done: How to get the latest ubuntu image for Beaglebone Black (via MicroSD Card)？ (20 replies)
# Scraping: https://forum.beagleboard.org/t/overlays-beaglebone-ai-64-pwm/32508?page=2
# Done: How to get the latest ubuntu image for Beaglebone Black (via MicroSD Card)？ (20 replies)
# Scraping: https://forum.beagleboard.org/t/overlays-beaglebone-ai-64-pwm/32508?page=2
# Done: Overlays: BeagleBone AI (17 replies)
# Scraping: https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318
# Done: Overlays: BeagleBone AI (17 replies)
# Scraping: https://forum.beagleboard.org/t/arm64-debian-11-x-bullseye-monthly-snapshots-2023-08-05/32318
# Done: ARM64 (2 replies)
# Scraping: https://forum.beagleboard.org/t/pwm-subdirectories-dissapeared-after-debian-update/31565
# Done: ARM64 (2 replies)
# Scraping: https://forum.beagleboard.org/t/pwm-subdirectories-dissapeared-after-debian-update/31565
# Done: PWM subdirectories dissapeared after Debian update (7 replies)
# Scraping: https://forum.beagleboard.org/t/can-t-install-gdb-or-gdb-server/35033
# Done: PWM subdirectories dissapeared after Debian update (7 replies)
# Scraping: https://forum.beagleboard.org/t/can-t-install-gdb-or-gdb-server/35033
# Done: can´t install gdb or gdb server (2 replies)
# Scraping: https://forum.beagleboard.org/t/tidl-edgeai-benchmarks-on-the-ai-64/32890
# Done: can´t install gdb or gdb server (2 replies)
# Scraping: https://forum.beagleboard.org/t/tidl-edgeai-benchmarks-on-the-ai-64/32890
# Done: TIDL/EdgeAI benchmarks on the AI (20 replies)
# Scraping: https://forum.beagleboard.org/t/vfs-unable-to-mount-root-fs-via-nfs/40199
# Done: TIDL/EdgeAI benchmarks on the AI (20 replies)
# Scraping: https://forum.beagleboard.org/t/vfs-unable-to-mount-root-fs-via-nfs/40199
# Done: VFS: Unable to mount root fs via nfs (2 replies)
# Scraping: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshot-2023-07-01-final/31203
# Done: VFS: Unable to mount root fs via nfs (2 replies)
# Scraping: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshot-2023-07-01-final/31203
# Done: Debian 10.x (Buster) (2 replies)
# Scraping: https://forum.beagleboard.org/t/how-to-check-revision-of-beagleboard/32112
# Done: Debian 10.x (Buster) (2 replies)
# Scraping: https://forum.beagleboard.org/t/how-to-check-revision-of-beagleboard/32112
# Done: How to check revision of beagleboard (1 replies)
# Scraping: https://forum.beagleboard.org/t/ai-64-streaming-h-264-encoded-video-from-an-imx219-csi-2-camera/34454
# Done: How to check revision of beagleboard (1 replies)
# Scraping: https://forum.beagleboard.org/t/ai-64-streaming-h-264-encoded-video-from-an-imx219-csi-2-camera/34454
# Done: AI (2 replies)
# Scraping: https://forum.beagleboard.org/t/new-beaglev-fire-getting-started-video/38029
# Done: AI (2 replies)
# Scraping: https://forum.beagleboard.org/t/new-beaglev-fire-getting-started-video/38029
# Done: New BeagleV (1 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-disable-mikrobus-to-free-gpio-pin/40496
# Done: New BeagleV (1 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-disable-mikrobus-to-free-gpio-pin/40496
# Done: BeaglePlay disable Mikrobus to free GPIO pin (10 replies)
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-upstream-greybus-module-for-zephyr/42126
# Done: BeaglePlay disable Mikrobus to free GPIO pin (10 replies)
# Scraping: https://forum.beagleboard.org/t/weekly-progress-report-upstream-greybus-module-for-zephyr/42126
# Done: Weekly Progress Report: Upstream Greybus Module for Zephyr (5 replies)
# Scraping: https://forum.beagleboard.org/t/upstream-linux-th1520-patch-series/35780
# Done: Weekly Progress Report: Upstream Greybus Module for Zephyr (5 replies)
# Scraping: https://forum.beagleboard.org/t/upstream-linux-th1520-patch-series/35780
# Done: Upstream Linux TH1520 patch series (4 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-board-hot-chips-are-not-placed-correctly/38119
# Done: Upstream Linux TH1520 patch series (4 replies)
# Scraping: https://forum.beagleboard.org/t/beagleplay-board-hot-chips-are-not-placed-correctly/38119
# Done: BeaglePlay board hot chips are not placed correctly (2 replies)
# Scraping: https://forum.beagleboard.org/t/got-started-next-steps/34756
# Done: BeaglePlay board hot chips are not placed correctly (2 replies)
# Scraping: https://forum.beagleboard.org/t/got-started-next-steps/34756
# Done: Got started.....next steps? (12 replies)
# Scraping: https://forum.beagleboard.org/t/minimal-cortex-r5-example-on-bbai-64/32443?page=2
# Done: Got started.....next steps? (12 replies)
# Scraping: https://forum.beagleboard.org/t/minimal-cortex-r5-example-on-bbai-64/32443?page=2
# Done: Minimal Cortex (18 replies)
# All threads scraped and saved to scraped_threads_complete.json
# Done: Minimal Cortex (18 replies)
# All threads scraped and saved to scraped_threads_complete.json

# %%
import os

# Load previously scraped results
with open('scraped_threads_complete.json', 'r', encoding='utf-8') as f:
    scraped = json.load(f)
existing_urls = set(item['url'] for item in scraped if item and 'url' in item)

# Find all thread URLs from filtered_threads.txt
with open('filtered_threads.txt', 'r') as f:
    all_links = [line.strip() for line in f if line.strip()]
all_thread_urls = set(normalize_thread_url(url) for url in all_links)

# Find failed URLs (not in scraped or with 0 replies)
failed_urls = [url for url in all_thread_urls if url not in existing_urls]
# Also retry any with 0 replies
failed_urls += [item['url'] for item in scraped if item.get('num_replies', 1) == 0]
failed_urls = list(set(failed_urls))

print(f"Retrying {len(failed_urls)} failed threads...")
new_results = []
for url in failed_urls:
    print(f"Retrying: {url}")
    data = scrape_thread(url)
    if data and data['num_replies'] > 0:
        new_results.append(data)
        print(f"Success: {data['thread_name']} ({data['num_replies']} replies)")
    else:
        print(f"Still failed: {url}")

# Append new results and save
if new_results:
    all_results = scraped + new_results
    # Remove duplicates by url
    unique = {}
    for item in all_results:
        if item and 'url' in item:
            unique[item['url']] = item
    with open('scraped_threads_complete.json', 'w', encoding='utf-8') as f:
        json.dump(list(unique.values()), f, ensure_ascii=False, indent=2)
    print(f"Added {len(new_results)} new threads to scraped_threads_complete.json")
else:
    print("No new threads were successfully scraped.")
# Out:
# Retrying 141 failed threads...
# Retrying: https://forum.beagleboard.org/t/debian-faq/30743
# Success: Debian FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/problems-to-do-login-in-openbeagle-org/39651
# Success: Debian FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/problems-to-do-login-in-openbeagle-org/39651
# Success: Problems to do login in openbeagle.org (6 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-control-fine-pwm-on-ai64/35539
# Success: Problems to do login in openbeagle.org (6 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-control-fine-pwm-on-ai64/35539
# Success: How to control fine PWM on AI64? (44 replies)
# Retrying: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Success: How to control fine PWM on AI64? (44 replies)
# Retrying: https://forum.beagleboard.org/t/i2c-bus-speed-beaglev-fire/41101
# Success: I2C bus speed BeagleV fire (12 replies)
# Retrying: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Success: I2C bus speed BeagleV fire (12 replies)
# Retrying: https://forum.beagleboard.org/t/change-direction-of-beagle-y-ai-gpio-without-being-in-supervisor-mode/42189
# Success: Change direction of Beagle Y AI GPIO without being in supervisor mode? (3 replies)
# Retrying: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Success: Change direction of Beagle Y AI GPIO without being in supervisor mode? (3 replies)
# Retrying: https://forum.beagleboard.org/t/urgently-needed-the-image-img-or-xyz-of-linux-beaglebone-4-19-94-ti-r42-1buster/38879
# Success: Urgently needed the image (.img or.xyz) of "Linux beaglebone 4.19.94 (6 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-general-discussion-category/27532
# Success: Urgently needed the image (.img or.xyz) of "Linux beaglebone 4.19.94 (6 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-general-discussion-category/27532
# Success: About the General Discussion category (3 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Success: About the General Discussion category (3 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-ubuntu-18-04-2-problem-with-robotcontrol/1474
# Success: Beaglebone Blue Ubuntu 18.04.2 problem with robotcontrol (8 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Success: Beaglebone Blue Ubuntu 18.04.2 problem with robotcontrol (8 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-wired-ethernet-doesnt-receive-packets/38994
# Success: beagleplay wired ethernet doesn't receive packets (7 replies)
# Retrying: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Success: beagleplay wired ethernet doesn't receive packets (7 replies)
# Retrying: https://forum.beagleboard.org/t/ai-64-remoteproc-confusion/32238
# Success: AI (26 replies)
# Retrying: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Success: AI (26 replies)
# Retrying: https://forum.beagleboard.org/t/need-to-enable-7-uart-on-beaglebone-ai-64/33936
# Success: Need to enable 7 UART on Beaglebone AI 64 (5 replies)
# Retrying: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Success: Need to enable 7 UART on Beaglebone AI 64 (5 replies)
# Retrying: https://forum.beagleboard.org/t/beaglecast-episode-on-beagley-ai/38030
# Success: BeagleCast episode on BeagleY (2 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Success: BeagleCast episode on BeagleY (2 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-black-industrial-fails-to-find-element-14-wireless-cape/39922
# Success: BeagleBone Black Industrial fails to find Element 14 Wireless Cape (5 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-xbee-adapter/33076
# Success: BeagleBone Black Industrial fails to find Element 14 Wireless Cape (5 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-xbee-adapter/33076
# Success: BBAI (2 replies)
# Retrying: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Success: BBAI (2 replies)
# Retrying: https://forum.beagleboard.org/t/pocketbeagle-2-with-am6254/42035
# Success: PocketBeagle 2 with AM6254 (2 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-gpu-marketing-part-number-mismatch/36423
# Success: PocketBeagle 2 with AM6254 (2 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-gpu-marketing-part-number-mismatch/36423
# Success: BeaglePlay (2 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-change-u-boot-console-from-uart0-to-uart5-in-beagle-bone-blue/36248
# Success: BeaglePlay (2 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-change-u-boot-console-from-uart0-to-uart5-in-beagle-bone-blue/36248
# Success: How to change U Boot console from UART0 to UART5 in beagle bone blue (3 replies)
# Retrying: https://forum.beagleboard.org/t/possibility-of-populating-different-polarfire-soc-parts/40463
# Success: How to change U Boot console from UART0 to UART5 in beagle bone blue (3 replies)
# Retrying: https://forum.beagleboard.org/t/possibility-of-populating-different-polarfire-soc-parts/40463
# Success: Possibility of populating different PolarFire SoC parts? (13 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Success: Possibility of populating different PolarFire SoC parts? (13 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-sd-card-boot-fail/35820
# Success: Beagleplay SD (15 replies)
# Retrying: https://forum.beagleboard.org/t/closing-to-do-items-on-docs-beagleboard-io/39264
# Success: Beagleplay SD (15 replies)
# Retrying: https://forum.beagleboard.org/t/closing-to-do-items-on-docs-beagleboard-io/39264
# Success: Closing to (3 replies)
# Retrying: https://forum.beagleboard.org/t/openbeagle-org-bbb-io-outage/38347
# Success: Closing to (3 replies)
# Retrying: https://forum.beagleboard.org/t/openbeagle-org-bbb-io-outage/38347
# Success: openbeagle.org, bbb.io outage (3 replies)
# Retrying: https://forum.beagleboard.org/t/boot-time-out-while-reading-emmc/42200
# Success: openbeagle.org, bbb.io outage (3 replies)
# Retrying: https://forum.beagleboard.org/t/boot-time-out-while-reading-emmc/42200
# Success: Boot time out while reading eMMC (2 replies)
# Retrying: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Success: Boot time out while reading eMMC (2 replies)
# Retrying: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Failed to fetch https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black: 404 Client Error: Not Found for url: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Still failed: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Retrying: https://forum.beagleboard.org/t/heat-dissipation-ai-64/32428
# Failed to fetch https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black: 404 Client Error: Not Found for url: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Still failed: https://forum.beagleboard.org/t/4-20-ma-measurement-with-beaglebone-black
# Retrying: https://forum.beagleboard.org/t/heat-dissipation-ai-64/32428
# Success: Heat Dissipation AI (5 replies)
# Retrying: https://forum.beagleboard.org/t/potential-tty-symlink-error-in-am335x-debian-11-5-minimal-armhf-2022-11-01-2gb-img-xz/33190
# Success: Heat Dissipation AI (5 replies)
# Retrying: https://forum.beagleboard.org/t/potential-tty-symlink-error-in-am335x-debian-11-5-minimal-armhf-2022-11-01-2gb-img-xz/33190
# Success: Potential tty symlink error in am335x (5 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-zigbee-how-to-block-all-signals-at-certain-time/40688
# Success: Potential tty symlink error in am335x (5 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-zigbee-how-to-block-all-signals-at-certain-time/40688
# Success: BeaglePlay + Zigbee, how to block all signals at certain time (1 replies)
# Retrying: https://forum.beagleboard.org/t/is-it-possible-to-run-the-bbb-off-cheap-rechargeable-batteries/17496
# Success: BeaglePlay + Zigbee, how to block all signals at certain time (1 replies)
# Retrying: https://forum.beagleboard.org/t/is-it-possible-to-run-the-bbb-off-cheap-rechargeable-batteries/17496
# Success: Is it possible to run the BBB off cheap rechargeable batteries? (3 replies)
# Retrying: https://forum.beagleboard.org/t/mail-link-goes-to-spam-google-chrome/29236
# Success: Is it possible to run the BBB off cheap rechargeable batteries? (3 replies)
# Retrying: https://forum.beagleboard.org/t/mail-link-goes-to-spam-google-chrome/29236
# Success: Mail link goes to spam Google Chrome (3 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Success: Mail link goes to spam Google Chrome (3 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboneblack-wireless-does-the-wifi-module-need-to-be-power-cycled-to-reset-after-suspend/1012
# Success: BeagleBoneBlack wireless — does the wifi module need to be power cycled to reset after suspend? (6 replies)
# Retrying: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Success: BeagleBoneBlack wireless — does the wifi module need to be power cycled to reset after suspend? (6 replies)
# Retrying: https://forum.beagleboard.org/t/kernel-module-cross-compilation/35579
# Success: Kernel module cross compilation (2 replies)
# Retrying: https://forum.beagleboard.org/t/getting-started-faq/34629
# Success: Kernel module cross compilation (2 replies)
# Retrying: https://forum.beagleboard.org/t/getting-started-faq/34629
# Success: Getting Started FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/once-compiled-how-does-one-install-the-tflite-runtime/39226
# Success: Getting Started FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/once-compiled-how-does-one-install-the-tflite-runtime/39226
# Success: once compiled, how does one install the tflite_runtime? (8 replies)
# Retrying: https://forum.beagleboard.org/t/beaglemind-conversational-ai-assistant-for-beagleboard-documentations/42038
# Success: once compiled, how does one install the tflite_runtime? (8 replies)
# Retrying: https://forum.beagleboard.org/t/beaglemind-conversational-ai-assistant-for-beagleboard-documentations/42038
# Success: Beaglemind, Conversational AI Assistant for BeagleBoard documentations (13 replies)
# Retrying: https://forum.beagleboard.org/t/dtb-for-bbblue-not-configuring-pru-pins/33628
# Success: Beaglemind, Conversational AI Assistant for BeagleBoard documentations (13 replies)
# Retrying: https://forum.beagleboard.org/t/dtb-for-bbblue-not-configuring-pru-pins/33628
# Success: Dtb for bbblue not configuring pru pins (1 replies)
# Retrying: https://forum.beagleboard.org/t/is-fic0-axi4-target-connection-necessary-for-a-custom-dma-controller-with-lsram-access/42190
# Success: Dtb for bbblue not configuring pru pins (1 replies)
# Retrying: https://forum.beagleboard.org/t/is-fic0-axi4-target-connection-necessary-for-a-custom-dma-controller-with-lsram-access/42190
# Success: Is FIC0_AXI4_TARGET connection necessary for a custom DMA controller with LSRAM access? (1 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-pinmux-spreedsheet/32418
# Success: Is FIC0_AXI4_TARGET connection necessary for a custom DMA controller with LSRAM access? (1 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-pinmux-spreedsheet/32418
# Success: BBAI (14 replies)
# Retrying: https://forum.beagleboard.org/t/set-up-capes-eeprom-i2c-2-beagleboneblack-rev-c/1074
# Success: BBAI (14 replies)
# Retrying: https://forum.beagleboard.org/t/set-up-capes-eeprom-i2c-2-beagleboneblack-rev-c/1074
# Success: Set up Cape's EEPROM i2c (8 replies)
# Retrying: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Success: Set up Cape's EEPROM i2c (8 replies)
# Retrying: https://forum.beagleboard.org/t/weekly-progress-report-low-latency-i-o-risc-v-cpu-core-in-fpga-fabric/38488
# Success: Weekly Progress Report: Low (24 replies)
# Retrying: https://forum.beagleboard.org/t/can-beagleboard-x15-run-on-lower-voltage-than-12v/32906
# Success: Weekly Progress Report: Low (24 replies)
# Retrying: https://forum.beagleboard.org/t/can-beagleboard-x15-run-on-lower-voltage-than-12v/32906
# Success: Can BeagleBoard (1 replies)
# Retrying: https://forum.beagleboard.org/t/slow/29179
# Success: Can BeagleBoard (1 replies)
# Retrying: https://forum.beagleboard.org/t/slow/29179
# Success: Slow! (7 replies)
# Retrying: https://forum.beagleboard.org/t/feature-request-new-post-by-email/31500
# Success: Slow! (7 replies)
# Retrying: https://forum.beagleboard.org/t/feature-request-new-post-by-email/31500
# Success: feature request: (new) post by email (8 replies)
# Retrying: https://forum.beagleboard.org/t/high-cpu-usage-for-irq-42-can0-if-bus-disconnected/1190
# Success: feature request: (new) post by email (8 replies)
# Retrying: https://forum.beagleboard.org/t/high-cpu-usage-for-irq-42-can0-if-bus-disconnected/1190
# Success: High cpu usage for irq/42 (2 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-check-the-processor-sdk-and-rto-in-beaglebone-ai-64/34893
# Success: High cpu usage for irq/42 (2 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-check-the-processor-sdk-and-rto-in-beaglebone-ai-64/34893
# Success: How to check the Processor SDK and RTO in beaglebone ai (4 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-use-apt-repos-on-beagleboard-io/37733
# Success: How to check the Processor SDK and RTO in beaglebone ai (4 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-use-apt-repos-on-beagleboard-io/37733
# Success: How to use apt repos on *.beagleboard.io (4 replies)
# Retrying: https://forum.beagleboard.org/t/pru-faq/30742
# Success: How to use apt repos on *.beagleboard.io (4 replies)
# Retrying: https://forum.beagleboard.org/t/pru-faq/30742
# Success: PRU FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Success: PRU FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/tivxalgivisioncreate-returned-null/38407
# Success: tivxAlgiVisionCreate returned NULL (9 replies)
# Retrying: https://forum.beagleboard.org/t/cannot-find-debian-jessie-8-9-version-for-beaglebone-black-rev-c/39614
# Success: tivxAlgiVisionCreate returned NULL (9 replies)
# Retrying: https://forum.beagleboard.org/t/cannot-find-debian-jessie-8-9-version-for-beaglebone-black-rev-c/39614
# Success: Cannot find Debian Jessie 8.9 version for BeagleBone Black Rev C (7 replies)
# Retrying: https://forum.beagleboard.org/t/ready-set-drivers-finding-the-correct-drivers-for-a-3-3v-beagleboard-org-board/40483
# Success: Cannot find Debian Jessie 8.9 version for BeagleBone Black Rev C (7 replies)
# Retrying: https://forum.beagleboard.org/t/ready-set-drivers-finding-the-correct-drivers-for-a-3-3v-beagleboard-org-board/40483
# Success: Ready, Set, Drivers/Finding the Correct Drivers for a 3.3v beagleboard.org Board! (7 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-bb-ai-64-wont-boot-after-kernel-linux-image-change/33732
# Success: Ready, Set, Drivers/Finding the Correct Drivers for a 3.3v beagleboard.org Board! (7 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-bb-ai-64-wont-boot-after-kernel-linux-image-change/33732
# Success: BeagleBone BB AI (3 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-black-wireless-connman-doesnt-exist/36015
# Success: BeagleBone BB AI (3 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-black-wireless-connman-doesnt-exist/36015
# Success: BeagleBone Black Wireless connman doesn't exist (13 replies)
# Retrying: https://forum.beagleboard.org/t/finding-current-image-in-beaglebone-black/29198
# Success: BeagleBone Black Wireless connman doesn't exist (13 replies)
# Retrying: https://forum.beagleboard.org/t/finding-current-image-in-beaglebone-black/29198
# Success: Finding current image in Beaglebone Black (18 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-job-board-category/30698
# Success: Finding current image in Beaglebone Black (18 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-job-board-category/30698
# Success: About the Job Board category (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-image-generation-sd-card-shell-script/41166
# Success: About the Job Board category (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-image-generation-sd-card-shell-script/41166
# Success: BeaglePlay: Image Generation (sd_card shell script) (4 replies)
# Retrying: https://forum.beagleboard.org/t/debouncing-pru-input-on-am5728/35858
# Success: BeaglePlay: Image Generation (sd_card shell script) (4 replies)
# Retrying: https://forum.beagleboard.org/t/debouncing-pru-input-on-am5728/35858
# Success: Debouncing PRU Input on AM5728 (2 replies)
# Retrying: https://forum.beagleboard.org/t/manually-parsing-eds-file-or-any-software-that-can-map-eds-files-to-i-o/40264
# Success: Debouncing PRU Input on AM5728 (2 replies)
# Retrying: https://forum.beagleboard.org/t/manually-parsing-eds-file-or-any-software-that-can-map-eds-files-to-i-o/40264
# Success: Manually Parsing EDS file or any Software that can map EDS files to I/O (7 replies)
# Retrying: https://forum.beagleboard.org/t/am335x-boneblue-dts-on-debian-11-x-iot-issue-id-like-to-contribute-the-fix/33483
# Success: Manually Parsing EDS file or any Software that can map EDS files to I/O (7 replies)
# Retrying: https://forum.beagleboard.org/t/am335x-boneblue-dts-on-debian-11-x-iot-issue-id-like-to-contribute-the-fix/33483
# Success: am335x (4 replies)
# Retrying: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565
# Success: am335x (4 replies)
# Retrying: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-09-02/35565
# Success: ARM64 (1 replies)
# Retrying: https://forum.beagleboard.org/t/contribution-faq/31455
# Success: ARM64 (1 replies)
# Retrying: https://forum.beagleboard.org/t/contribution-faq/31455
# Success: Contribution FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Success: Contribution FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/error-message-when-cloning-pru-cookbook/33664
# Success: BBB: Error message when cloning PRU Cookbook (4 replies)
# Retrying: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Success: BBB: Error message when cloning PRU Cookbook (4 replies)
# Retrying: https://forum.beagleboard.org/t/kernel-panic-on-boot/38690
# Success: kernel panic on boot (9 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-site-feedback-category
# Success: kernel panic on boot (9 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-site-feedback-category
# Success: About the Site Feedback category (2 replies)
# Retrying: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Success: About the Site Feedback category (2 replies)
# Retrying: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203
# Success: Debian 10.x (Buster) (2 replies)
# Retrying: https://forum.beagleboard.org/t/does-beagleplay-ethernet-support-wake-on-lan-wol/41054
# Success: Debian 10.x (Buster) (2 replies)
# Retrying: https://forum.beagleboard.org/t/does-beagleplay-ethernet-support-wake-on-lan-wol/41054
# Success: Does BeaglePlay Ethernet Support Wake (3 replies)
# Retrying: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Success: Does BeaglePlay Ethernet Support Wake (3 replies)
# Retrying: https://forum.beagleboard.org/t/arm64-debian-12-x-bookworm-monthly-snapshots-2023-10-07/35565
# Success: ARM64 (1 replies)
# Retrying: https://forum.beagleboard.org/t/pixhawlk-px4-on-bb-ai64/39818
# Success: ARM64 (1 replies)
# Retrying: https://forum.beagleboard.org/t/pixhawlk-px4-on-bb-ai64/39818
# Success: Pixhawlk PX4 on BB (5 replies)
# Retrying: https://forum.beagleboard.org/t/thanks-for-respecting-the-freedom-of-the-users/31202
# Success: Pixhawlk PX4 on BB (5 replies)
# Retrying: https://forum.beagleboard.org/t/thanks-for-respecting-the-freedom-of-the-users/31202
# Success: Thanks for respecting the freedom of the users (2 replies)
# Retrying: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Success: Thanks for respecting the freedom of the users (2 replies)
# Retrying: https://forum.beagleboard.org/t/is-a-dt-overlay-the-only-thing-needed-to-get-a-rgb-16-bit-display-to-work-over-dss-dpi-on-the-pocketbeagle2/41708
# Success: Is a DT overlay the only thing needed to get a RGB 16 (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-wl-chip-dies-after-3-months-of-usage/40277
# Success: Is a DT overlay the only thing needed to get a RGB 16 (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-wl-chip-dies-after-3-months-of-usage/40277
# Success: BeaglePlay WL chip dies after 3 months of usage. (7 replies)
# Retrying: https://forum.beagleboard.org/t/what-are-the-machine-learning-tools-in-debian-buster/33025
# Success: BeaglePlay WL chip dies after 3 months of usage. (7 replies)
# Retrying: https://forum.beagleboard.org/t/what-are-the-machine-learning-tools-in-debian-buster/33025
# Success: What are the machine learning tools in Debian Buster? (3 replies)
# Retrying: https://forum.beagleboard.org/t/powervr-firmware-problem-with-video-driver/42082
# Success: What are the machine learning tools in Debian Buster? (3 replies)
# Retrying: https://forum.beagleboard.org/t/powervr-firmware-problem-with-video-driver/42082
# Success: PowerVR: Firmware (Problem with Video driver) (5 replies)
# Retrying: https://forum.beagleboard.org/t/fresh-boot-only-cylon-leds-blinking-then-powers-down-everytime/34775
# Success: PowerVR: Firmware (Problem with Video driver) (5 replies)
# Retrying: https://forum.beagleboard.org/t/fresh-boot-only-cylon-leds-blinking-then-powers-down-everytime/34775
# Success: fresh boot..only cylon leds blinking...then powers down (12 replies)
# Retrying: https://forum.beagleboard.org/t/logging-data-from-encoders/35432
# Success: fresh boot..only cylon leds blinking...then powers down (12 replies)
# Retrying: https://forum.beagleboard.org/t/logging-data-from-encoders/35432
# Success: logging data from encoders (2 replies)
# Retrying: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Success: logging data from encoders (2 replies)
# Retrying: https://forum.beagleboard.org/t/zephyr-related-projects-for-2025/40001
# Success: Zephyr (5 replies)
# Retrying: https://forum.beagleboard.org/t/flashed-latest-iot-version-on-bb-blue-how-do-i-get-started-with-robotics/36372
# Success: Zephyr (5 replies)
# Retrying: https://forum.beagleboard.org/t/flashed-latest-iot-version-on-bb-blue-how-do-i-get-started-with-robotics/36372
# Success: Flashed latest IoT version on BB Blue, how do I get started with robotics (2 replies)
# Retrying: https://forum.beagleboard.org/t/archlinux-and-gentoo-on-beagleplay/41866
# Success: Flashed latest IoT version on BB Blue, how do I get started with robotics (2 replies)
# Retrying: https://forum.beagleboard.org/t/archlinux-and-gentoo-on-beagleplay/41866
# Success: Archlinux and Gentoo on beagleplay (4 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-ssh-over-usb-a-to-other-beagleboard/40606
# Success: Archlinux and Gentoo on beagleplay (4 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-ssh-over-usb-a-to-other-beagleboard/40606
# Success: BeaglePlay SSH over USB (6 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-showing-2gb-of-ram-in-htop/33039
# Success: BeaglePlay SSH over USB (6 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-showing-2gb-of-ram-in-htop/33039
# Success: Beaglebone AI 64 showing 2GB of RAM in htop (16 replies)
# Retrying: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Success: Beaglebone AI 64 showing 2GB of RAM in htop (16 replies)
# Retrying: https://forum.beagleboard.org/t/re-shorts-and-ideas-that-may-be-shorter-open-chips-cat/29214
# Success: RE: Shorts and Ideas that may be Shorter/Open Chips Cat (4 replies)
# Retrying: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Success: RE: Shorts and Ideas that may be Shorter/Open Chips Cat (4 replies)
# Retrying: https://forum.beagleboard.org/t/safe-procedure-to-downgrade-kernel-for-minimal-image-and-resonably-stable-kernel/32693
# Success: Safe procedure to downgrade kernel for "minimal" image and resonably stable kernel (13 replies)
# Retrying: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Success: Safe procedure to downgrade kernel for "minimal" image and resonably stable kernel (13 replies)
# Retrying: https://forum.beagleboard.org/t/2020-04-06-how-to-add-hdmi-back-into-bbb-image-after-init-emmc-flasher-v3-sh/33134
# Success: [2020 (7 replies)
# Retrying: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Success: [2020 (7 replies)
# Retrying: https://forum.beagleboard.org/t/teensy-esp32-other-microcontroller-beagleboard-some-cape-ideas/33728
# Success: Teensy/ESP32/Other Microcontroller 'Beagleboard'  & some Cape ideas (2 replies)
# Retrying: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Success: Teensy/ESP32/Other Microcontroller 'Beagleboard'  & some Cape ideas (2 replies)
# Retrying: https://forum.beagleboard.org/t/usb-and-ethernet-interfaces-are-not-visible-to-me/36157
# Success: USB and ethernet interfaces are not visible to me. (13 replies)
# Retrying: https://forum.beagleboard.org/t/c-programing-of-uart-peripheral-in-beaglebone-black-linux/1659
# Success: USB and ethernet interfaces are not visible to me. (13 replies)
# Retrying: https://forum.beagleboard.org/t/c-programing-of-uart-peripheral-in-beaglebone-black-linux/1659
# Success: C programing of Uart peripheral in beaglebone black (Linux) (15 replies)
# Retrying: https://forum.beagleboard.org/t/device-tree-faq/31451
# Success: C programing of Uart peripheral in beaglebone black (Linux) (15 replies)
# Retrying: https://forum.beagleboard.org/t/device-tree-faq/31451
# Success: Device tree FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboard-debian-how-to-download-kernel-source-packages/30524
# Success: Device tree FAQ (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboard-debian-how-to-download-kernel-source-packages/30524
# Success: [BeagleBoard][Debian] How to download kernel source packages. (4 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Success: [BeagleBoard][Debian] How to download kernel source packages. (4 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-adc-voltage-question/42211
# Success: Beaglebone AI (1 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Success: Beaglebone AI (1 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-get-the-latest-ubuntu-image-for-beaglebone-black-via-microsd-card/31484
# Success: How to get the latest ubuntu image for Beaglebone Black (via MicroSD Card)？ (64 replies)
# Retrying: https://forum.beagleboard.org/t/connectivity-between-two-bbai64-with-ethernet-switch/36607
# Success: How to get the latest ubuntu image for Beaglebone Black (via MicroSD Card)？ (64 replies)
# Retrying: https://forum.beagleboard.org/t/connectivity-between-two-bbai64-with-ethernet-switch/36607
# Success: Connectivity between two BBAI64 with Ethernet Switch (9 replies)
# Retrying: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Success: Connectivity between two BBAI64 with Ethernet Switch (9 replies)
# Retrying: https://forum.beagleboard.org/t/how-long-until-my-posts-do-no-have-to-be-approved/30525
# Success: How long until my posts do no have to be approved? (3 replies)
# Retrying: https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015
# Success: How long until my posts do no have to be approved? (3 replies)
# Retrying: https://forum.beagleboard.org/t/job-openings-at-texas-instruments-india-for-1-2-years-experience/38015
# Success: Job Openings at Texas Instruments India for 1 (1 replies)
# Retrying: https://forum.beagleboard.org/t/old-news-and-new-news-bbb-and-kernels/37248
# Success: Job Openings at Texas Instruments India for 1 (1 replies)
# Retrying: https://forum.beagleboard.org/t/old-news-and-new-news-bbb-and-kernels/37248
# Success: Old News and New News/BBB and Kernels (5 replies)
# Retrying: https://forum.beagleboard.org/t/integration-of-gsm-lte-modem-a7672s/39567
# Success: Old News and New News/BBB and Kernels (5 replies)
# Retrying: https://forum.beagleboard.org/t/integration-of-gsm-lte-modem-a7672s/39567
# Success: Integration of GSM LTE Modem A7672S (19 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-to-do-projects-category/39262
# Success: Integration of GSM LTE Modem A7672S (19 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-to-do-projects-category/39262
# Success: About the To (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-dfu-not-working/37150
# Success: About the To (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleplay-dfu-not-working/37150
# Success: Beagleplay DFU not working (4 replies)
# Retrying: https://forum.beagleboard.org/t/mss-gpio-configuration/42024
# Success: Beagleplay DFU not working (4 replies)
# Retrying: https://forum.beagleboard.org/t/mss-gpio-configuration/42024
# Success: MSS GPIO configuration (1 replies)
# Retrying: https://forum.beagleboard.org/t/about-google-summer-of-code/27544
# Success: MSS GPIO configuration (1 replies)
# Retrying: https://forum.beagleboard.org/t/about-google-summer-of-code/27544
# Success: About Google Summer of Code (1 replies)
# Retrying: https://forum.beagleboard.org/t/balenaetcher-known-good-versions/41655
# Success: About Google Summer of Code (1 replies)
# Retrying: https://forum.beagleboard.org/t/balenaetcher-known-good-versions/41655
# Success: balenaEtcher: known good versions (1 replies)
# Retrying: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Success: balenaEtcher: known good versions (1 replies)
# Retrying: https://forum.beagleboard.org/t/beaglev-fire-os-updating/41914
# Success: beaglev (3 replies)
# Retrying: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203/
# Success: beaglev (3 replies)
# Retrying: https://forum.beagleboard.org/t/debian-10-x-buster-monthly-snapshots/31203/
# Success: Debian 10.x (Buster) (2 replies)
# Retrying: https://forum.beagleboard.org/t/beaglemind/40806
# Success: Debian 10.x (Buster) (2 replies)
# Retrying: https://forum.beagleboard.org/t/beaglemind/40806
# Success: BeagleMind (62 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914
# Success: BeagleMind (62 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b850e000>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Still failed: https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914
# Retrying: https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644
# Failed to fetch https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fe0b850e000>: Failed to resolve 'forum.beagleboard.org' ([Errno -3] Temporary failure in name resolution)"))
# Still failed: https://forum.beagleboard.org/t/beaglebone-ai-64-documentation-for-gpio-pwm-and-analog-pins/32914
# Retrying: https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644
# Failed to fetch https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/modulenotfounderror-no-module-named-onnxruntime/33644 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fe0b8176e70>, 'Connection to forum.beagleboard.org timed out. (connect timeout=10)'))
# Still failed: https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644
# Retrying: https://forum.beagleboard.org/t/about-the-open-chips-category/29029
# Failed to fetch https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/modulenotfounderror-no-module-named-onnxruntime/33644 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fe0b8176e70>, 'Connection to forum.beagleboard.org timed out. (connect timeout=10)'))
# Still failed: https://forum.beagleboard.org/t/modulenotfounderror-no-module-named-onnxruntime/33644
# Retrying: https://forum.beagleboard.org/t/about-the-open-chips-category/29029
# Failed to fetch https://forum.beagleboard.org/t/about-the-open-chips-category/29029: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/about-the-open-chips-category/29029 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b9735f10>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Still failed: https://forum.beagleboard.org/t/about-the-open-chips-category/29029
# Retrying: https://forum.beagleboard.org/t/error-while-copy-emmc-to-sd/42194
# Failed to fetch https://forum.beagleboard.org/t/about-the-open-chips-category/29029: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/about-the-open-chips-category/29029 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b9735f10>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Still failed: https://forum.beagleboard.org/t/about-the-open-chips-category/29029
# Retrying: https://forum.beagleboard.org/t/error-while-copy-emmc-to-sd/42194
# Success: Error while copy eMmc to sd (2 replies)
# Retrying: https://forum.beagleboard.org/t/not-able-to-boot-via-sd-card-in-my-beaglebone-black-element14/157
# Success: Error while copy eMmc to sd (2 replies)
# Retrying: https://forum.beagleboard.org/t/not-able-to-boot-via-sd-card-in-my-beaglebone-black-element14/157
# Success: Not able to boot via SD Card in my beaglebone black element14 (20 replies)
# Retrying: https://forum.beagleboard.org/t/new-forum-beagleboard-org-categories-outside-of-videos-boards/35873
# Success: Not able to boot via SD Card in my beaglebone black element14 (20 replies)
# Retrying: https://forum.beagleboard.org/t/new-forum-beagleboard-org-categories-outside-of-videos-boards/35873
# Success: New forum.beagleboard.org Categories Outside of Videos...Boards! (3 replies)
# Retrying: https://forum.beagleboard.org/t/re-capes-workings-and-tutorials-seth/29676
# Success: New forum.beagleboard.org Categories Outside of Videos...Boards! (3 replies)
# Retrying: https://forum.beagleboard.org/t/re-capes-workings-and-tutorials-seth/29676
# Success: RE: Capes, Workings, and Tutorials/Seth (14 replies)
# Retrying: https://forum.beagleboard.org/t/is-robotics-cape-compatible-with-the-bb-ai64/39820
# Success: RE: Capes, Workings, and Tutorials/Seth (14 replies)
# Retrying: https://forum.beagleboard.org/t/is-robotics-cape-compatible-with-the-bb-ai64/39820
# Success: Is Robotics CAPE compatible with the BB (6 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474
# Success: Is Robotics CAPE compatible with the BB (6 replies)
# Retrying: https://forum.beagleboard.org/t/bbai-64-device-tree-overlays/32474
# Success: BBAI (3 replies)
# Retrying: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Success: BBAI (3 replies)
# Retrying: https://forum.beagleboard.org/t/notes-on-installing-ubuntu-18-04-2-with-ros-melodic-and-robotcontrol-pre-installed-for-beaglebone-blue/1485
# Success: Notes on installing Ubuntu 18.04.2 with ROS melodic and robotcontrol pre (2 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-faq-category/30739
# Success: Notes on installing Ubuntu 18.04.2 with ROS melodic and robotcontrol pre (2 replies)
# Retrying: https://forum.beagleboard.org/t/about-the-faq-category/30739
# Success: About the FAQ category (1 replies)
# Retrying: https://forum.beagleboard.org/t/welcome-to-the-beagleboard-org-discourse
# Success: About the FAQ category (1 replies)
# Retrying: https://forum.beagleboard.org/t/welcome-to-the-beagleboard-org-discourse
# Success: Welcome to the BeagleBoard.org Discourse! (5 replies)
# Retrying: https://forum.beagleboard.org/t/polarfire-soc-linux-examples-dma-test-on-beaglev-fire/38980
# Success: Welcome to the BeagleBoard.org Discourse! (5 replies)
# Retrying: https://forum.beagleboard.org/t/polarfire-soc-linux-examples-dma-test-on-beaglev-fire/38980
# Success: polarfire (4 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-use-pru-constants-table/25113
# Success: polarfire (4 replies)
# Retrying: https://forum.beagleboard.org/t/how-to-use-pru-constants-table/25113
# Success: How to use PRU constants table? (9 replies)
# Retrying: https://forum.beagleboard.org/t/upstream-graphic-status-for-imgtech-as-of-2025/41608
# Success: How to use PRU constants table? (9 replies)
# Retrying: https://forum.beagleboard.org/t/upstream-graphic-status-for-imgtech-as-of-2025/41608
# Success: Upstream graphic status for Imgtech (as of 2025) (2 replies)
# Retrying: https://forum.beagleboard.org/t/dark-mode/41365
# Success: Upstream graphic status for Imgtech (as of 2025) (2 replies)
# Retrying: https://forum.beagleboard.org/t/dark-mode/41365
# Success: Dark mode (1 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-autonomous-file-transfer-over-ethernet/13293
# Success: Dark mode (1 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-autonomous-file-transfer-over-ethernet/13293
# Success: [Beaglebone] Autonomous file transfer over ethernet (10 replies)
# Retrying: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Success: [Beaglebone] Autonomous file transfer over ethernet (10 replies)
# Retrying: https://forum.beagleboard.org/t/failed-to-write-to-state-settings-enospc-no-space-left-on-device/36098
# Success: Failed to write to 'state.settings'. ENOSPC: no space left on device. (17 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-cannot-detect-i2c-devices/676?page=2
# Success: Failed to write to 'state.settings'. ENOSPC: no space left on device. (17 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-cannot-detect-i2c-devices/676?page=2
# Success: BeagleBone Blue cannot detect i2c devices (5 replies)
# Retrying: https://forum.beagleboard.org/t/tiao-usb-multi-protocol-adapter-help/33512
# Success: BeagleBone Blue cannot detect i2c devices (5 replies)
# Retrying: https://forum.beagleboard.org/t/tiao-usb-multi-protocol-adapter-help/33512
# Success: TIAO USB Multi (3 replies)
# Retrying: https://forum.beagleboard.org/t/highly-experienced-embedded-engineer-fpga-rtos/34647
# Success: TIAO USB Multi (3 replies)
# Retrying: https://forum.beagleboard.org/t/highly-experienced-embedded-engineer-fpga-rtos/34647
# Success: Highly Experienced Embedded Engineer (FPGA / RTOS) (2 replies)
# Retrying: https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662
# Success: Highly Experienced Embedded Engineer (FPGA / RTOS) (2 replies)
# Retrying: https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662
# Failed to fetch https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8584ad0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Still failed: https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662
# Retrying: https://forum.beagleboard.org/t/microchip-mss-configuration-files-for-v-fire/38346
# Failed to fetch https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662: HTTPSConnectionPool(host='forum.beagleboard.org', port=443): Max retries exceeded with url: /t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe0b8584ad0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Still failed: https://forum.beagleboard.org/t/am335x-emmc-flasher-debian-11-7-iot-armhf-2023-09-02-4gb-img-xz-toolchain/39662
# Retrying: https://forum.beagleboard.org/t/microchip-mss-configuration-files-for-v-fire/38346
# Success: Microchip MSS configuration files for V (4 replies)
# Retrying: https://forum.beagleboard.org/t/bbbw-indicator-leds-not-working/31383
# Success: Microchip MSS configuration files for V (4 replies)
# Retrying: https://forum.beagleboard.org/t/bbbw-indicator-leds-not-working/31383
# Success: BBBW Indicator LEDs Not Working? (13 replies)
# Retrying: https://forum.beagleboard.org/t/nearing-buster-distribution-eol/31745
# Success: BBBW Indicator LEDs Not Working? (13 replies)
# Retrying: https://forum.beagleboard.org/t/nearing-buster-distribution-eol/31745
# Success: Nearing Buster distribution EOL (3 replies)
# Retrying: https://forum.beagleboard.org/t/pocketbeagle-2-ethernet-cape/41642
# Success: Nearing Buster distribution EOL (3 replies)
# Retrying: https://forum.beagleboard.org/t/pocketbeagle-2-ethernet-cape/41642
# Success: PocketBeagle 2 ethernet cape (24 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-segmentation-error-python-motors/34779
# Success: PocketBeagle 2 ethernet cape (24 replies)
# Retrying: https://forum.beagleboard.org/t/beaglebone-blue-segmentation-error-python-motors/34779
# Success: BeagleBone Blue segmentation error Python motors (2 replies)
# Retrying: https://forum.beagleboard.org/t/beagle-board-x15-board-bring-up/31218
# Success: BeagleBone Blue segmentation error Python motors (2 replies)
# Retrying: https://forum.beagleboard.org/t/beagle-board-x15-board-bring-up/31218
# Success: Beagle board x15 board bring up (2 replies)
# Retrying: https://forum.beagleboard.org/t/fire-corei2c-driver-bugs-when-using-i2cdetect-random-results/42004
# Success: Beagle board x15 board bring up (2 replies)
# Retrying: https://forum.beagleboard.org/t/fire-corei2c-driver-bugs-when-using-i2cdetect-random-results/42004
# Success: Fire corei2c driver bugs when using i2cdetect (random results) (6 replies)
# Retrying: https://forum.beagleboard.org/t/debian-on-am57xx/40994
# Success: Fire corei2c driver bugs when using i2cdetect (random results) (6 replies)
# Retrying: https://forum.beagleboard.org/t/debian-on-am57xx/40994
# Success: Debian on am57xx (1 replies)
# Retrying: https://forum.beagleboard.org/t/u-boot-creation-on-beagleplay/41030
# Success: Debian on am57xx (1 replies)
# Retrying: https://forum.beagleboard.org/t/u-boot-creation-on-beagleplay/41030
# Success: u (12 replies)
# Retrying: https://forum.beagleboard.org/t/yocto-using-beagle-bone-xm-dm3730cbp/40486
# Success: u (12 replies)
# Retrying: https://forum.beagleboard.org/t/yocto-using-beagle-bone-xm-dm3730cbp/40486
# Success: Yocto using Beagle Bone XM (DM3730CBP) (1 replies)
# Retrying: https://forum.beagleboard.org/t/source-code-and-testing-in-c-c-files-with-the-beagley-ai/42205
# Success: Yocto using Beagle Bone XM (DM3730CBP) (1 replies)
# Retrying: https://forum.beagleboard.org/t/source-code-and-testing-in-c-c-files-with-the-beagley-ai/42205
# Success: Source Code and Testing in C/C++ Files with the BeagleY (1 replies)
# Retrying: https://forum.beagleboard.org/t/ai-64-how-to-flash-emmc/32384
# Success: Source Code and Testing in C/C++ Files with the BeagleY (1 replies)
# Retrying: https://forum.beagleboard.org/t/ai-64-how-to-flash-emmc/32384
# Success: AI (8 replies)
# Retrying: https://forum.beagleboard.org/t/issue-with-uart-disappearing-when-using-i2c-on-beaglebone-ai-64/38951
# Success: AI (8 replies)
# Retrying: https://forum.beagleboard.org/t/issue-with-uart-disappearing-when-using-i2c-on-beaglebone-ai-64/38951
# Success: Issue with UART Disappearing When Using I2C on BeagleBone AI (6 replies)
# Retrying: https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318
# Success: Issue with UART Disappearing When Using I2C on BeagleBone AI (6 replies)
# Retrying: https://forum.beagleboard.org/t/192-168-7-2-is-not-opening-or-reachable/2318
# Success: 192.168.7.2 is NOT opening or reachable (54 replies)
# Retrying: https://forum.beagleboard.org/t/ccs-beaglebone-black/34054
# Success: 192.168.7.2 is NOT opening or reachable (54 replies)
# Retrying: https://forum.beagleboard.org/t/ccs-beaglebone-black/34054
# Success: CCS调试beaglebone black失败 (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboard-x15-access-serial-console-through-usb/32391
# Success: CCS调试beaglebone black失败 (1 replies)
# Retrying: https://forum.beagleboard.org/t/beagleboard-x15-access-serial-console-through-usb/32391
# Success: Beagleboard x15: access serial console through USB (6 replies)
# Retrying: https://forum.beagleboard.org/t/debian-bullseye-on-beagleboard-x15/29298
# Success: Beagleboard x15: access serial console through USB (6 replies)
# Retrying: https://forum.beagleboard.org/t/debian-bullseye-on-beagleboard-x15/29298
# Success: Debian Bullseye on Beagleboard X15? (4 replies)
# Retrying: https://forum.beagleboard.org/t/pwm-not-present-in-bb-blue/34957
# Success: Debian Bullseye on Beagleboard X15? (4 replies)
# Retrying: https://forum.beagleboard.org/t/pwm-not-present-in-bb-blue/34957
# Success: pwm not present in BB blue (13 replies)
# Retrying: https://forum.beagleboard.org/t/weekly-updates-update-beagle-tester-for-mainline-testing/42174
# Success: pwm not present in BB blue (13 replies)
# Retrying: https://forum.beagleboard.org/t/weekly-updates-update-beagle-tester-for-mainline-testing/42174
# Success: [Weekly Updates] Update Beagle (4 replies)
# Added 136 new threads to scraped_threads_complete.json
# Success: [Weekly Updates] Update Beagle (4 replies)
# Added 136 new threads to scraped_threads_complete.json
